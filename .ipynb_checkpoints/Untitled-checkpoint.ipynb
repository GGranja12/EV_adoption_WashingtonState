# %%
import requests

url = "https://electric-vehicle-data2.p.rapidapi.com/records"
querystring = {"dataListIndex":">=0","limit":"1000","orderBy":"dataListIndex_asc","index":"0"}

headers = {
	"x-rapidapi-key": "017c936a82msh8860646249c65a4p13c03bjsn9438dd108cbd",
	"x-rapidapi-host": "electric-vehicle-data2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

response.json()
# Out:
# {'data': [{'dataListIndex': '0',
#    'vin': 'KM8K33AGXL',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98103',
#    'modelYear': '2020',
#    'make': 'HYUNDAI',
#    'model': 'KONA',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '258',
#    'baseMsrp': '0',
#    'legislativeDistrict': '43',
#    'dolVehicleId': '249675142',
#    'vehicleLocation': 'POINT (-122.34301 47.659185)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033004800'},
#   {'dataListIndex': '1',
#    'vin': '1C4RJYB61N',
#    'county': 'King',
#    'city': 'Bothell',
#    'state': 'WA',
#    'postalCode': '98011',
#    'modelYear': '2022',
#    'make': 'JEEP',
#    'model': 'GRAND CHEROKEE',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '25',
#    'baseMsrp': '0',
#    'legislativeDistrict': '1',
#    'dolVehicleId': '233928502',
#    'vehicleLocation': 'POINT (-122.20578 47.762405)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033021804'},
#   {'dataListIndex': '2',
#    'vin': '1C4RJYD61P',
#    'county': 'Yakima',
#    'city': 'Yakima',
#    'state': 'WA',
#    'postalCode': '98908',
#    'modelYear': '2023',
#    'make': 'JEEP',
#    'model': 'GRAND CHEROKEE',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '25',
#    'baseMsrp': '0',
#    'legislativeDistrict': '14',
#    'dolVehicleId': '229675939',
#    'vehicleLocation': 'POINT (-120.6027202 46.5965625)',
#    'electricUtility': 'PACIFICORP',
#    'CensusTract': '53077002900'},
#   {'dataListIndex': '3',
#    'vin': '5YJ3E1EA7J',
#    'county': 'King',
#    'city': 'Kirkland',
#    'state': 'WA',
#    'postalCode': '98034',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '215',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '104714466',
#    'vehicleLocation': 'POINT (-122.209285 47.71124)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033021903'},
#   {'dataListIndex': '4',
#    'vin': 'WBY7Z8C5XJ',
#    'county': 'Thurston',
#    'city': 'Olympia',
#    'state': 'WA',
#    'postalCode': '98501',
#    'modelYear': '2018',
#    'make': 'BMW',
#    'model': 'I3',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '97',
#    'baseMsrp': '0',
#    'legislativeDistrict': '22',
#    'dolVehicleId': '185498386',
#    'vehicleLocation': 'POINT (-122.89692 47.043535)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067010700'},
#   {'dataListIndex': '5',
#    'vin': '5YJ3E1EAXL',
#    'county': 'Snohomish',
#    'city': 'Marysville',
#    'state': 'WA',
#    'postalCode': '98271',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '266',
#    'baseMsrp': '0',
#    'legislativeDistrict': '38',
#    'dolVehicleId': '124595523',
#    'vehicleLocation': 'POINT (-122.1713847 48.10433)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061940001'},
#   {'dataListIndex': '6',
#    'vin': '2C4RC1N77H',
#    'county': 'King',
#    'city': 'Kent',
#    'state': 'WA',
#    'postalCode': '98042',
#    'modelYear': '2017',
#    'make': 'CHRYSLER',
#    'model': 'PACIFICA',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '33',
#    'baseMsrp': '0',
#    'legislativeDistrict': '47',
#    'dolVehicleId': '1815593',
#    'vehicleLocation': 'POINT (-122.111625 47.36078)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033031707'},
#   {'dataListIndex': '7',
#    'vin': '5YJYGDEE3L',
#    'county': 'King',
#    'city': 'Woodinville',
#    'state': 'WA',
#    'postalCode': '98072',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '291',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '124760555',
#    'vehicleLocation': 'POINT (-122.151665 47.75855)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033021906'},
#   {'dataListIndex': '8',
#    'vin': '5YJ3E1EA1J',
#    'county': 'Island',
#    'city': 'Coupeville',
#    'state': 'WA',
#    'postalCode': '98239',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '215',
#    'baseMsrp': '0',
#    'legislativeDistrict': '10',
#    'dolVehicleId': '125048003',
#    'vehicleLocation': 'POINT (-122.6880708 48.2179983)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53029971000'},
#   {'dataListIndex': '9',
#    'vin': '7SAYGDEF0P',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98004',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '48',
#    'dolVehicleId': '240416207',
#    'vehicleLocation': 'POINT (-122.201905 47.61385)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033023806'},
#   {'dataListIndex': '10',
#    'vin': '5YJ3E1EA7J',
#    'county': 'King',
#    'city': 'Kirkland',
#    'state': 'WA',
#    'postalCode': '98033',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '215',
#    'baseMsrp': '0',
#    'legislativeDistrict': '48',
#    'dolVehicleId': '231013436',
#    'vehicleLocation': 'POINT (-122.20264 47.6785)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033022603'},
#   {'dataListIndex': '11',
#    'vin': '3FA6P0SU9G',
#    'county': 'Kitsap',
#    'city': 'Port Orchard',
#    'state': 'WA',
#    'postalCode': '98367',
#    'modelYear': '2016',
#    'make': 'FORD',
#    'model': 'FUSION',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '19',
#    'baseMsrp': '0',
#    'legislativeDistrict': '26',
#    'dolVehicleId': '212561716',
#    'vehicleLocation': 'POINT (-122.6851642 47.506453)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035092902'},
#   {'dataListIndex': '12',
#    'vin': 'JTDKARFP9H',
#    'county': 'Kitsap',
#    'city': 'Port Orchard',
#    'state': 'WA',
#    'postalCode': '98366',
#    'modelYear': '2017',
#    'make': 'TOYOTA',
#    'model': 'PRIUS PRIME',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '25',
#    'baseMsrp': '0',
#    'legislativeDistrict': '26',
#    'dolVehicleId': '229764972',
#    'vehicleLocation': 'POINT (-122.639265 47.5373)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035092600'},
#   {'dataListIndex': '13',
#    'vin': '5YJ3E1EB8K',
#    'county': 'Snohomish',
#    'city': 'Mukilteo',
#    'state': 'WA',
#    'postalCode': '98275',
#    'modelYear': '2019',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '220',
#    'baseMsrp': '0',
#    'legislativeDistrict': '21',
#    'dolVehicleId': '179728755',
#    'vehicleLocation': 'POINT (-122.299965 47.94171)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061041301'},
#   {'dataListIndex': '14',
#    'vin': '5YJ3E1EA5K',
#    'county': 'King',
#    'city': 'Redmond',
#    'state': 'WA',
#    'postalCode': '98052',
#    'modelYear': '2019',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '220',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '120633516',
#    'vehicleLocation': 'POINT (-122.12302 47.67668)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032323'},
#   {'dataListIndex': '15',
#    'vin': '3FA6P0SU0D',
#    'county': 'Thurston',
#    'city': 'Rochester',
#    'state': 'WA',
#    'postalCode': '98579',
#    'modelYear': '2013',
#    'make': 'FORD',
#    'model': 'FUSION',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '19',
#    'baseMsrp': '0',
#    'legislativeDistrict': '20',
#    'dolVehicleId': '138697212',
#    'vehicleLocation': 'POINT (-123.09573 46.82158)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067012730'},
#   {'dataListIndex': '16',
#    'vin': 'WA1VABGE4K',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98112',
#    'modelYear': '2019',
#    'make': 'AUDI',
#    'model': 'E-TRON',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '204',
#    'baseMsrp': '0',
#    'legislativeDistrict': '43',
#    'dolVehicleId': '475364046',
#    'vehicleLocation': 'POINT (-122.306935 47.62441)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033006400'},
#   {'dataListIndex': '17',
#    'vin': '1N4AZ0CP6F',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98125',
#    'modelYear': '2015',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '46',
#    'dolVehicleId': '252522896',
#    'vehicleLocation': 'POINT (-122.296385 47.71558)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033000201'},
#   {'dataListIndex': '18',
#    'vin': 'KNDCC3LD7K',
#    'county': 'Kitsap',
#    'city': 'Bremerton',
#    'state': 'WA',
#    'postalCode': '98311',
#    'modelYear': '2019',
#    'make': 'KIA',
#    'model': 'NIRO',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '26',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '2148170',
#    'vehicleLocation': 'POINT (-122.6468815 47.6344364)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035091204'},
#   {'dataListIndex': '19',
#    'vin': '1N4AZ0CP1E',
#    'county': 'Kitsap',
#    'city': 'Poulsbo',
#    'state': 'WA',
#    'postalCode': '98370',
#    'modelYear': '2014',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '258176922',
#    'vehicleLocation': 'POINT (-122.64177 47.737525)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035091100'},
#   {'dataListIndex': '20',
#    'vin': '5UXKT0C51J',
#    'county': 'King',
#    'city': 'Kent',
#    'state': 'WA',
#    'postalCode': '98042',
#    'modelYear': '2018',
#    'make': 'BMW',
#    'model': 'X5',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '13',
#    'baseMsrp': '0',
#    'legislativeDistrict': '47',
#    'dolVehicleId': '291897987',
#    'vehicleLocation': 'POINT (-122.111625 47.36078)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033031708'},
#   {'dataListIndex': '21',
#    'vin': '5YJSA1E22J',
#    'county': 'Snohomish',
#    'city': 'Marysville',
#    'state': 'WA',
#    'postalCode': '98271',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL S',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '249',
#    'baseMsrp': '0',
#    'legislativeDistrict': '39',
#    'dolVehicleId': '172808163',
#    'vehicleLocation': 'POINT (-122.1713847 48.10433)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061052808'},
#   {'dataListIndex': '22',
#    'vin': '1G1RB6E46D',
#    'county': 'Kitsap',
#    'city': 'Bremerton',
#    'state': 'WA',
#    'postalCode': '98312',
#    'modelYear': '2013',
#    'make': 'CHEVROLET',
#    'model': 'VOLT',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '38',
#    'baseMsrp': '0',
#    'legislativeDistrict': '35',
#    'dolVehicleId': '138557555',
#    'vehicleLocation': 'POINT (-122.65223 47.57192)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035080700'},
#   {'dataListIndex': '23',
#    'vin': '2T3YL4DV5E',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98108',
#    'modelYear': '2014',
#    'make': 'TOYOTA',
#    'model': 'RAV4',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '103',
#    'baseMsrp': '0',
#    'legislativeDistrict': '11',
#    'dolVehicleId': '183567149',
#    'vehicleLocation': 'POINT (-122.326965 47.55015)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033010001'},
#   {'dataListIndex': '24',
#    'vin': 'JTDKARFP5H',
#    'county': 'Snohomish',
#    'city': 'Lake Stevens',
#    'state': 'WA',
#    'postalCode': '98258',
#    'modelYear': '2017',
#    'make': 'TOYOTA',
#    'model': 'PRIUS PRIME',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '25',
#    'baseMsrp': '0',
#    'legislativeDistrict': '44',
#    'dolVehicleId': '160057901',
#    'vehicleLocation': 'POINT (-122.112265 48.0047)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061052607'},
#   {'dataListIndex': '25',
#    'vin': '5YJ3E1EB6L',
#    'county': 'Kitsap',
#    'city': 'Silverdale',
#    'state': 'WA',
#    'postalCode': '98383',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '322',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '6335647',
#    'vehicleLocation': 'POINT (-122.668076 47.665978)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035091302'},
#   {'dataListIndex': '26',
#    'vin': '5YJ3E1EB3J',
#    'county': 'King',
#    'city': 'Kirkland',
#    'state': 'WA',
#    'postalCode': '98033',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '215',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '205530552',
#    'vehicleLocation': 'POINT (-122.20264 47.6785)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033022401'},
#   {'dataListIndex': '27',
#    'vin': '1FADP5CU0G',
#    'county': 'Kitsap',
#    'city': 'Kingston',
#    'state': 'WA',
#    'postalCode': '98346',
#    'modelYear': '2016',
#    'make': 'FORD',
#    'model': 'C-MAX',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '19',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '1465033',
#    'vehicleLocation': 'POINT (-122.50156 47.8019)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035090102'},
#   {'dataListIndex': '28',
#    'vin': 'WVWKR7AU0K',
#    'county': 'King',
#    'city': 'Kirkland',
#    'state': 'WA',
#    'postalCode': '98033',
#    'modelYear': '2019',
#    'make': 'VOLKSWAGEN',
#    'model': 'E-GOLF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '125',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '306865107',
#    'vehicleLocation': 'POINT (-122.20264 47.6785)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033022006'},
#   {'dataListIndex': '29',
#    'vin': '5YJSA1E29L',
#    'county': 'Kitsap',
#    'city': 'Kingston',
#    'state': 'WA',
#    'postalCode': '98346',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL S',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '330',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '110621444',
#    'vehicleLocation': 'POINT (-122.50156 47.8019)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035090102'},
#   {'dataListIndex': '30',
#    'vin': '1N4AZ0CP7F',
#    'county': 'Thurston',
#    'city': 'Olympia',
#    'state': 'WA',
#    'postalCode': '98506',
#    'modelYear': '2015',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '22',
#    'dolVehicleId': '141547311',
#    'vehicleLocation': 'POINT (-122.8874781 47.0519573)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067010200'},
#   {'dataListIndex': '31',
#    'vin': 'WA1LAAGE7M',
#    'county': 'Yakima',
#    'city': 'Yakima',
#    'state': 'WA',
#    'postalCode': '98908',
#    'modelYear': '2021',
#    'make': 'AUDI',
#    'model': 'E-TRON',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '222',
#    'baseMsrp': '0',
#    'legislativeDistrict': '14',
#    'dolVehicleId': '144941534',
#    'vehicleLocation': 'POINT (-120.6027202 46.5965625)',
#    'electricUtility': 'PACIFICORP',
#    'CensusTract': '53077002801'},
#   {'dataListIndex': '32',
#    'vin': 'KNDCE3LG9K',
#    'county': 'King',
#    'city': 'Enumclaw',
#    'state': 'WA',
#    'postalCode': '98022',
#    'modelYear': '2019',
#    'make': 'KIA',
#    'model': 'NIRO',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '239',
#    'baseMsrp': '0',
#    'legislativeDistrict': '31',
#    'dolVehicleId': '117615928',
#    'vehicleLocation': 'POINT (-121.98953 47.20347)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033031400'},
#   {'dataListIndex': '33',
#    'vin': '1N4AZ0CP9F',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98109',
#    'modelYear': '2015',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '43',
#    'dolVehicleId': '180279487',
#    'vehicleLocation': 'POINT (-122.34848 47.632405)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033007301'},
#   {'dataListIndex': '34',
#    'vin': '5YJ3E1EA4P',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98006',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '241481278',
#    'vehicleLocation': 'POINT (-122.16937 47.571015)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033024704'},
#   {'dataListIndex': '35',
#    'vin': 'JN1AZ0CP1B',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98133',
#    'modelYear': '2011',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '73',
#    'baseMsrp': '0',
#    'legislativeDistrict': '32',
#    'dolVehicleId': '133592196',
#    'vehicleLocation': 'POINT (-122.34584 47.76726)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033000404'},
#   {'dataListIndex': '36',
#    'vin': '3C3CFFGE4G',
#    'county': 'King',
#    'city': 'Auburn',
#    'state': 'WA',
#    'postalCode': '98002',
#    'modelYear': '2016',
#    'make': 'FIAT',
#    'model': '500',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '47',
#    'dolVehicleId': '225708626',
#    'vehicleLocation': 'POINT (-122.222855 47.305065)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033030600'},
#   {'dataListIndex': '37',
#    'vin': '1G1FY6S07L',
#    'county': 'Yakima',
#    'city': 'Moxee',
#    'state': 'WA',
#    'postalCode': '98936',
#    'modelYear': '2020',
#    'make': 'CHEVROLET',
#    'model': 'BOLT EV',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '259',
#    'baseMsrp': '0',
#    'legislativeDistrict': '15',
#    'dolVehicleId': '125943058',
#    'vehicleLocation': 'POINT (-120.3795117 46.55609)',
#    'electricUtility': 'PACIFICORP',
#    'CensusTract': '53077001702'},
#   {'dataListIndex': '38',
#    'vin': '1V2DNPE83P',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98125',
#    'modelYear': '2023',
#    'make': 'VOLKSWAGEN',
#    'model': 'ID.4',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '46',
#    'dolVehicleId': '245619664',
#    'vehicleLocation': 'POINT (-122.296385 47.71558)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033000900'},
#   {'dataListIndex': '39',
#    'vin': '1G1FY6S06N',
#    'county': 'Yakima',
#    'city': 'Tieton',
#    'state': 'WA',
#    'postalCode': '98947',
#    'modelYear': '2022',
#    'make': 'CHEVROLET',
#    'model': 'BOLT EV',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '14',
#    'dolVehicleId': '208932349',
#    'vehicleLocation': 'POINT (-120.75692 46.70383)',
#    'electricUtility': 'PACIFICORP',
#    'CensusTract': '53077002900'},
#   {'dataListIndex': '40',
#    'vin': '1N4AZ0CPXD',
#    'county': 'Kitsap',
#    'city': 'Silverdale',
#    'state': 'WA',
#    'postalCode': '98383',
#    'modelYear': '2013',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '75',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '144485785',
#    'vehicleLocation': 'POINT (-122.668076 47.665978)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035091205'},
#   {'dataListIndex': '41',
#    'vin': '3MW39FS02P',
#    'county': 'Kitsap',
#    'city': 'Port Orchard',
#    'state': 'WA',
#    'postalCode': '98367',
#    'modelYear': '2023',
#    'make': 'BMW',
#    'model': '330E',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '20',
#    'baseMsrp': '0',
#    'legislativeDistrict': '35',
#    'dolVehicleId': '244137120',
#    'vehicleLocation': 'POINT (-122.6851642 47.506453)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035092901'},
#   {'dataListIndex': '42',
#    'vin': '1N4BZ1CP2K',
#    'county': 'King',
#    'city': 'Renton',
#    'state': 'WA',
#    'postalCode': '98057',
#    'modelYear': '2019',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '150',
#    'baseMsrp': '0',
#    'legislativeDistrict': '11',
#    'dolVehicleId': '4870099',
#    'vehicleLocation': 'POINT (-122.21024 47.4797047)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033026200'},
#   {'dataListIndex': '43',
#    'vin': 'WAUTPBFF2H',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98008',
#    'modelYear': '2017',
#    'make': 'AUDI',
#    'model': 'A3',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '16',
#    'baseMsrp': '0',
#    'legislativeDistrict': '48',
#    'dolVehicleId': '159300466',
#    'vehicleLocation': 'POINT (-122.11832 47.6245)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033023300'},
#   {'dataListIndex': '44',
#    'vin': '2C4RC1L73P',
#    'county': 'King',
#    'city': 'Tukwila',
#    'state': 'WA',
#    'postalCode': '98188',
#    'modelYear': '2023',
#    'make': 'CHRYSLER',
#    'model': 'PACIFICA',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '32',
#    'baseMsrp': '0',
#    'legislativeDistrict': '11',
#    'dolVehicleId': '236367519',
#    'vehicleLocation': 'POINT (-122.29179 47.43473)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033028200'},
#   {'dataListIndex': '45',
#    'vin': '5YJ3E1EA7K',
#    'county': 'King',
#    'city': 'Seatac',
#    'state': 'WA',
#    'postalCode': '98188',
#    'modelYear': '2019',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '220',
#    'baseMsrp': '0',
#    'legislativeDistrict': '33',
#    'dolVehicleId': '216597293',
#    'vehicleLocation': 'POINT (-122.29179 47.43473)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033028300'},
#   {'dataListIndex': '46',
#    'vin': '1FADP3R40D',
#    'county': 'Thurston',
#    'city': 'Tumwater',
#    'state': 'WA',
#    'postalCode': '98501',
#    'modelYear': '2013',
#    'make': 'FORD',
#    'model': 'FOCUS',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '76',
#    'baseMsrp': '0',
#    'legislativeDistrict': '35',
#    'dolVehicleId': '230763249',
#    'vehicleLocation': 'POINT (-122.89692 47.043535)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067011720'},
#   {'dataListIndex': '47',
#    'vin': '2C4RC1N79J',
#    'county': 'Kitsap',
#    'city': 'Suquamish',
#    'state': 'WA',
#    'postalCode': '98392',
#    'modelYear': '2018',
#    'make': 'CHRYSLER',
#    'model': 'PACIFICA',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '33',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '176286988',
#    'vehicleLocation': 'POINT (-122.55717 47.733415)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035940100'},
#   {'dataListIndex': '48',
#    'vin': 'KNDRJDLH0N',
#    'county': 'Yakima',
#    'city': 'Yakima',
#    'state': 'WA',
#    'postalCode': '98908',
#    'modelYear': '2022',
#    'make': 'KIA',
#    'model': 'SORENTO',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '32',
#    'baseMsrp': '0',
#    'legislativeDistrict': '14',
#    'dolVehicleId': '209591812',
#    'vehicleLocation': 'POINT (-120.6027202 46.5965625)',
#    'electricUtility': 'PACIFICORP',
#    'CensusTract': '53077000800'},
#   {'dataListIndex': '49',
#    'vin': '3FA6P0SU1H',
#    'county': 'Island',
#    'city': 'Oak Harbor',
#    'state': 'WA',
#    'postalCode': '98277',
#    'modelYear': '2017',
#    'make': 'FORD',
#    'model': 'FUSION',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '21',
#    'baseMsrp': '0',
#    'legislativeDistrict': '10',
#    'dolVehicleId': '250570589',
#    'vehicleLocation': 'POINT (-122.67499 48.287295)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53029970500'},
#   {'dataListIndex': '50',
#    'vin': '5YJ3E1EA8K',
#    'county': 'Snohomish',
#    'city': 'Bothell',
#    'state': 'WA',
#    'postalCode': '98012',
#    'modelYear': '2019',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '220',
#    'baseMsrp': '0',
#    'legislativeDistrict': '1',
#    'dolVehicleId': '338436920',
#    'vehicleLocation': 'POINT (-122.1876761 47.820517)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061052107'},
#   {'dataListIndex': '51',
#    'vin': 'KNDCS3LF7P',
#    'county': 'King',
#    'city': 'Shoreline',
#    'state': 'WA',
#    'postalCode': '98133',
#    'modelYear': '2023',
#    'make': 'KIA',
#    'model': 'NIRO',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '33',
#    'baseMsrp': '0',
#    'legislativeDistrict': '32',
#    'dolVehicleId': '240355930',
#    'vehicleLocation': 'POINT (-122.34584 47.76726)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033020700'},
#   {'dataListIndex': '52',
#    'vin': '5YJ3E1EBXK',
#    'county': 'King',
#    'city': 'Shoreline',
#    'state': 'WA',
#    'postalCode': '98177',
#    'modelYear': '2019',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '220',
#    'baseMsrp': '0',
#    'legislativeDistrict': '32',
#    'dolVehicleId': '310953751',
#    'vehicleLocation': 'POINT (-122.382425 47.77279)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033020100'},
#   {'dataListIndex': '53',
#    'vin': '1G1FZ6S0XL',
#    'county': 'Kitsap',
#    'city': 'Seabeck',
#    'state': 'WA',
#    'postalCode': '98380',
#    'modelYear': '2020',
#    'make': 'CHEVROLET',
#    'model': 'BOLT EV',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '259',
#    'baseMsrp': '0',
#    'legislativeDistrict': '35',
#    'dolVehicleId': '138832844',
#    'vehicleLocation': 'POINT (-122.847462 47.63836)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035092000'},
#   {'dataListIndex': '54',
#    'vin': 'JT3GS10V32',
#    'county': 'King',
#    'city': 'Sammamish',
#    'state': 'WA',
#    'postalCode': '98075',
#    'modelYear': '2002',
#    'make': 'TOYOTA',
#    'model': 'RAV4',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '95',
#    'baseMsrp': '0',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '175935672',
#    'vehicleLocation': 'POINT (-122.03309 47.58153)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032207'},
#   {'dataListIndex': '55',
#    'vin': '5YJ3E1EA1J',
#    'county': 'King',
#    'city': 'Issaquah',
#    'state': 'WA',
#    'postalCode': '98027',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '215',
#    'baseMsrp': '0',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '347726956',
#    'vehicleLocation': 'POINT (-122.03646 47.534065)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033025006'},
#   {'dataListIndex': '56',
#    'vin': 'KM8JFDA26P',
#    'county': 'Snohomish',
#    'city': 'Monroe',
#    'state': 'WA',
#    'postalCode': '98272',
#    'modelYear': '2023',
#    'make': 'HYUNDAI',
#    'model': 'TUCSON',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '33',
#    'baseMsrp': '0',
#    'legislativeDistrict': '39',
#    'dolVehicleId': '252501987',
#    'vehicleLocation': 'POINT (-121.972215 47.85674)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061052203'},
#   {'dataListIndex': '57',
#    'vin': '5YJXCBE41G',
#    'county': 'Kitsap',
#    'city': 'Silverdale',
#    'state': 'WA',
#    'postalCode': '98383',
#    'modelYear': '2016',
#    'make': 'TESLA',
#    'model': 'MODEL X',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '200',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '226085744',
#    'vehicleLocation': 'POINT (-122.668076 47.665978)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035091302'},
#   {'dataListIndex': '58',
#    'vin': 'WBY1Z4C53E',
#    'county': 'Kitsap',
#    'city': 'Bainbridge Island',
#    'state': 'WA',
#    'postalCode': '98110',
#    'modelYear': '2014',
#    'make': 'BMW',
#    'model': 'I3',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '72',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '243689834',
#    'vehicleLocation': 'POINT (-122.5235781 47.6293323)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035091002'},
#   {'dataListIndex': '59',
#    'vin': '1G1FY6S04L',
#    'county': 'King',
#    'city': 'Shoreline',
#    'state': 'WA',
#    'postalCode': '98177',
#    'modelYear': '2020',
#    'make': 'CHEVROLET',
#    'model': 'BOLT EV',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '259',
#    'baseMsrp': '0',
#    'legislativeDistrict': '32',
#    'dolVehicleId': '101572810',
#    'vehicleLocation': 'POINT (-122.382425 47.77279)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033020800'},
#   {'dataListIndex': '60',
#    'vin': 'KNDRJDLH5N',
#    'county': 'Thurston',
#    'city': 'Yelm',
#    'state': 'WA',
#    'postalCode': '98597',
#    'modelYear': '2022',
#    'make': 'KIA',
#    'model': 'SORENTO',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '32',
#    'baseMsrp': '0',
#    'legislativeDistrict': '2',
#    'dolVehicleId': '207310582',
#    'vehicleLocation': 'POINT (-122.61023 46.94126)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067012530'},
#   {'dataListIndex': '61',
#    'vin': 'WBA8E1C50H',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98006',
#    'modelYear': '2017',
#    'make': 'BMW',
#    'model': '330E',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '14',
#    'baseMsrp': '44100',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '477193174',
#    'vehicleLocation': 'POINT (-122.16937 47.571015)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033024901'},
#   {'dataListIndex': '62',
#    'vin': '5YJSA1CPXD',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98112',
#    'modelYear': '2013',
#    'make': 'TESLA',
#    'model': 'MODEL S',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '208',
#    'baseMsrp': '69900',
#    'legislativeDistrict': '43',
#    'dolVehicleId': '103275168',
#    'vehicleLocation': 'POINT (-122.306935 47.62441)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033006300'},
#   {'dataListIndex': '63',
#    'vin': 'JN1AZ0CP5C',
#    'county': 'Snohomish',
#    'city': 'Lake Stevens',
#    'state': 'WA',
#    'postalCode': '98258',
#    'modelYear': '2012',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '73',
#    'baseMsrp': '0',
#    'legislativeDistrict': '44',
#    'dolVehicleId': '165573152',
#    'vehicleLocation': 'POINT (-122.112265 48.0047)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061052607'},
#   {'dataListIndex': '64',
#    'vin': '5YJYGDEE8L',
#    'county': 'Thurston',
#    'city': 'Tumwater',
#    'state': 'WA',
#    'postalCode': '98501',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '291',
#    'baseMsrp': '0',
#    'legislativeDistrict': '35',
#    'dolVehicleId': '124633715',
#    'vehicleLocation': 'POINT (-122.89692 47.043535)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067011720'},
#   {'dataListIndex': '65',
#    'vin': 'JN1AZ0CP1C',
#    'county': 'King',
#    'city': 'Kenmore',
#    'state': 'WA',
#    'postalCode': '98028',
#    'modelYear': '2012',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '73',
#    'baseMsrp': '0',
#    'legislativeDistrict': '46',
#    'dolVehicleId': '158914675',
#    'vehicleLocation': 'POINT (-122.2504747 47.7617128)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033022102'},
#   {'dataListIndex': '66',
#    'vin': '5YJXCDE4XL',
#    'county': 'Thurston',
#    'city': 'Olympia',
#    'state': 'WA',
#    'postalCode': '98502',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL X',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '289',
#    'baseMsrp': '0',
#    'legislativeDistrict': '22',
#    'dolVehicleId': '127274675',
#    'vehicleLocation': 'POINT (-122.92145 47.045935)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067011100'},
#   {'dataListIndex': '67',
#    'vin': '2C4RC1N70L',
#    'county': 'Thurston',
#    'city': 'Olympia',
#    'state': 'WA',
#    'postalCode': '98501',
#    'modelYear': '2020',
#    'make': 'CHRYSLER',
#    'model': 'PACIFICA',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '32',
#    'baseMsrp': '0',
#    'legislativeDistrict': '22',
#    'dolVehicleId': '139479049',
#    'vehicleLocation': 'POINT (-122.89692 47.043535)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067010400'},
#   {'dataListIndex': '68',
#    'vin': 'YV4BR0DM4L',
#    'county': 'King',
#    'city': 'Burien',
#    'state': 'WA',
#    'postalCode': '98166',
#    'modelYear': '2020',
#    'make': 'VOLVO',
#    'model': 'XC60',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '19',
#    'baseMsrp': '0',
#    'legislativeDistrict': '34',
#    'dolVehicleId': '106963650',
#    'vehicleLocation': 'POINT (-122.34102 47.46593)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033027800'},
#   {'dataListIndex': '69',
#    'vin': '1N4AZ0CP9D',
#    'county': 'King',
#    'city': 'Tukwila',
#    'state': 'WA',
#    'postalCode': '98168',
#    'modelYear': '2013',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '75',
#    'baseMsrp': '0',
#    'legislativeDistrict': '11',
#    'dolVehicleId': '164742420',
#    'vehicleLocation': 'POINT (-122.286465 47.476)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033026200'},
#   {'dataListIndex': '70',
#    'vin': '5YJSA1DP8D',
#    'county': 'Snohomish',
#    'city': 'Stanwood',
#    'state': 'WA',
#    'postalCode': '98292',
#    'modelYear': '2013',
#    'make': 'TESLA',
#    'model': 'MODEL S',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '208',
#    'baseMsrp': '69900',
#    'legislativeDistrict': '10',
#    'dolVehicleId': '111162012',
#    'vehicleLocation': 'POINT (-122.3684051 48.2414921)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061053202'},
#   {'dataListIndex': '71',
#    'vin': '1G1RC6S53J',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98109',
#    'modelYear': '2018',
#    'make': 'CHEVROLET',
#    'model': 'VOLT',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '53',
#    'baseMsrp': '0',
#    'legislativeDistrict': '36',
#    'dolVehicleId': '180154600',
#    'vehicleLocation': 'POINT (-122.34848 47.632405)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033006800'},
#   {'dataListIndex': '72',
#    'vin': 'JN1AZ0CP0C',
#    'county': 'King',
#    'city': 'Sammamish',
#    'state': 'WA',
#    'postalCode': '98075',
#    'modelYear': '2012',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '73',
#    'baseMsrp': '0',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '122729736',
#    'vehicleLocation': 'POINT (-122.03309 47.58153)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032213'},
#   {'dataListIndex': '73',
#    'vin': '5YJ3E1EA4P',
#    'county': 'Kitsap',
#    'city': 'Poulsbo',
#    'state': 'WA',
#    'postalCode': '98370',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '233664560',
#    'vehicleLocation': 'POINT (-122.64177 47.737525)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035090502'},
#   {'dataListIndex': '74',
#    'vin': '5YJYGDEE8M',
#    'county': 'Snohomish',
#    'city': 'Arlington',
#    'state': 'WA',
#    'postalCode': '98223',
#    'modelYear': '2021',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '39',
#    'dolVehicleId': '169400570',
#    'vehicleLocation': 'POINT (-122.12324 48.19485)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061053507'},
#   {'dataListIndex': '75',
#    'vin': 'KNDJP3AE1G',
#    'county': 'King',
#    'city': 'Maple Valley',
#    'state': 'WA',
#    'postalCode': '98038',
#    'modelYear': '2016',
#    'make': 'KIA',
#    'model': 'SOUL',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '93',
#    'baseMsrp': '31950',
#    'legislativeDistrict': '5',
#    'dolVehicleId': '263895950',
#    'vehicleLocation': 'POINT (-122.05191 47.357985)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032011'},
#   {'dataListIndex': '76',
#    'vin': 'KNDPZDAH8P',
#    'county': 'Kitsap',
#    'city': 'Poulsbo',
#    'state': 'WA',
#    'postalCode': '98370',
#    'modelYear': '2023',
#    'make': 'KIA',
#    'model': 'SPORTAGE',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '34',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '241599438',
#    'vehicleLocation': 'POINT (-122.64177 47.737525)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035090201'},
#   {'dataListIndex': '77',
#    'vin': 'WVGJNPE23N',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98116',
#    'modelYear': '2022',
#    'make': 'VOLKSWAGEN',
#    'model': 'ID.4',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '34',
#    'dolVehicleId': '225909687',
#    'vehicleLocation': 'POINT (-122.38679 47.56484)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033009702'},
#   {'dataListIndex': '78',
#    'vin': '5UXTA6C04N',
#    'county': 'Kitsap',
#    'city': 'Bremerton',
#    'state': 'WA',
#    'postalCode': '98312',
#    'modelYear': '2022',
#    'make': 'BMW',
#    'model': 'X5',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '30',
#    'baseMsrp': '0',
#    'legislativeDistrict': '35',
#    'dolVehicleId': '194341269',
#    'vehicleLocation': 'POINT (-122.65223 47.57192)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035080900'},
#   {'dataListIndex': '79',
#    'vin': '5YJXCDE22J',
#    'county': 'King',
#    'city': 'Medina',
#    'state': 'WA',
#    'postalCode': '98039',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL X',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
# ...
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '161599014',
#    'vehicleLocation': 'POINT (-122.0370611 47.6887161)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032332'},
#   {'dataListIndex': '475',
#    'vin': '1N4BZ1CP0K',
#    'county': 'Whatcom',
#    'city': 'Bellingham',
#    'state': 'WA',
#    'postalCode': '98225',
#    'modelYear': '2019',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '150',
#    'baseMsrp': '0',
#    'legislativeDistrict': '40',
#    'dolVehicleId': '477314127',
#    'vehicleLocation': 'POINT (-122.486115 48.761615)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM COUNTY',
#    'CensusTract': '53073001202'},
#   {'dataListIndex': '476',
#    'vin': '1N4AZ0CP6E',
#    'county': 'Snohomish',
#    'city': 'Marysville',
#    'state': 'WA',
#    'postalCode': '98270',
#    'modelYear': '2014',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '38',
#    'dolVehicleId': '289423739',
#    'vehicleLocation': 'POINT (-122.17673 48.05542)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061052904'},
#   {'dataListIndex': '477',
#    'vin': '5YJ3E1EA5P',
#    'county': 'King',
#    'city': 'Issaquah',
#    'state': 'WA',
#    'postalCode': '98029',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '5',
#    'dolVehicleId': '239781069',
#    'vehicleLocation': 'POINT (-121.999595 47.547635)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032220'},
#   {'dataListIndex': '478',
#    'vin': '5YJ3E1EA2L',
#    'county': 'Kitsap',
#    'city': 'Port Orchard',
#    'state': 'WA',
#    'postalCode': '98366',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '266',
#    'baseMsrp': '0',
#    'legislativeDistrict': '26',
#    'dolVehicleId': '6249078',
#    'vehicleLocation': 'POINT (-122.639265 47.5373)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035092600'},
#   {'dataListIndex': '479',
#    'vin': '5YJ3E1EB5P',
#    'county': 'King',
#    'city': 'Shoreline',
#    'state': 'WA',
#    'postalCode': '98177',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '32',
#    'dolVehicleId': '245715844',
#    'vehicleLocation': 'POINT (-122.382425 47.77279)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033020800'},
#   {'dataListIndex': '480',
#    'vin': '7SAYGDEE2P',
#    'county': 'Clark',
#    'city': 'La Center',
#    'state': 'WA',
#    'postalCode': '98629',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '18',
#    'dolVehicleId': '251668329',
#    'vehicleLocation': 'POINT (-122.6706246 45.8662548)',
#    'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)',
#    'CensusTract': '53011040201'},
#   {'dataListIndex': '481',
#    'vin': 'YV4BR0CL6K',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98177',
#    'modelYear': '2019',
#    'make': 'VOLVO',
#    'model': 'XC90',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '17',
#    'baseMsrp': '0',
#    'legislativeDistrict': '36',
#    'dolVehicleId': '326903881',
#    'vehicleLocation': 'POINT (-122.382425 47.77279)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033001600'},
#   {'dataListIndex': '482',
#    'vin': '5YJSA1E26J',
#    'county': 'Pierce',
#    'city': 'Lakewood',
#    'state': 'WA',
#    'postalCode': '98498',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL S',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '249',
#    'baseMsrp': '0',
#    'legislativeDistrict': '28',
#    'dolVehicleId': '131349165',
#    'vehicleLocation': 'POINT (-122.547645 47.176685)',
#    'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY',
#    'CensusTract': '53053072106'},
#   {'dataListIndex': '483',
#    'vin': 'JTMABABA9P',
#    'county': 'King',
#    'city': 'Tukwila',
#    'state': 'WA',
#    'postalCode': '98188',
#    'modelYear': '2023',
#    'make': 'SUBARU',
#    'model': 'SOLTERRA',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '11',
#    'dolVehicleId': '252339734',
#    'vehicleLocation': 'POINT (-122.29179 47.43473)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033028200'},
#   {'dataListIndex': '484',
#    'vin': '5YJXCAE2XL',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98008',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL X',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '293',
#    'baseMsrp': '0',
#    'legislativeDistrict': '48',
#    'dolVehicleId': '2096342',
#    'vehicleLocation': 'POINT (-122.11832 47.6245)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033023100'},
#   {'dataListIndex': '485',
#    'vin': '1N4BZ0CP6H',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98006',
#    'modelYear': '2017',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '107',
#    'baseMsrp': '0',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '348003407',
#    'vehicleLocation': 'POINT (-122.16937 47.571015)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033024905'},
#   {'dataListIndex': '486',
#    'vin': '7SAYGDEE4P',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98005',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '232642511',
#    'vehicleLocation': 'POINT (-122.16085 47.624515)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033023601'},
#   {'dataListIndex': '487',
#    'vin': 'WAUSPBFF1H',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98102',
#    'modelYear': '2017',
#    'make': 'AUDI',
#    'model': 'A3',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '16',
#    'baseMsrp': '0',
#    'legislativeDistrict': '43',
#    'dolVehicleId': '135207054',
#    'vehicleLocation': 'POINT (-122.3223156 47.6402108)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033007501'},
#   {'dataListIndex': '488',
#    'vin': '7SAYGDEE0P',
#    'county': 'King',
#    'city': 'Woodinville',
#    'state': 'WA',
#    'postalCode': '98072',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '230807286',
#    'vehicleLocation': 'POINT (-122.151665 47.75855)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033021906'},
#   {'dataListIndex': '489',
#    'vin': '1N4BZ1CP4K',
#    'county': 'Clark',
#    'city': 'Vancouver',
#    'state': 'WA',
#    'postalCode': '98682',
#    'modelYear': '2019',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '150',
#    'baseMsrp': '0',
#    'legislativeDistrict': '17',
#    'dolVehicleId': '106928818',
#    'vehicleLocation': 'POINT (-122.5146473 45.67862)',
#    'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)',
#    'CensusTract': '53011040713'},
#   {'dataListIndex': '490',
#    'vin': '5YJ3E1EB0M',
#    'county': 'King',
#    'city': 'Woodinville',
#    'state': 'WA',
#    'postalCode': '98072',
#    'modelYear': '2021',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '161665864',
#    'vehicleLocation': 'POINT (-122.151665 47.75855)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033021802'},
#   {'dataListIndex': '491',
#    'vin': '7SAYGDEE3P',
#    'county': 'Clark',
#    'city': 'Brush Prairie',
#    'state': 'WA',
#    'postalCode': '98606',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '17',
#    'dolVehicleId': '223894352',
#    'vehicleLocation': 'POINT (-122.5485715 45.7336587)',
#    'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)',
#    'CensusTract': '53011040715'},
#   {'dataListIndex': '492',
#    'vin': '1V25MPE80P',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98103',
#    'modelYear': '2023',
#    'make': 'VOLKSWAGEN',
#    'model': 'ID.4',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '43',
#    'dolVehicleId': '240635825',
#    'vehicleLocation': 'POINT (-122.34301 47.659185)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033005000'},
#   {'dataListIndex': '493',
#    'vin': '5YJXCBE45H',
#    'county': 'King',
#    'city': 'Kent',
#    'state': 'WA',
#    'postalCode': '98031',
#    'modelYear': '2017',
#    'make': 'TESLA',
#    'model': 'MODEL X',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '200',
#    'baseMsrp': '0',
#    'legislativeDistrict': '47',
#    'dolVehicleId': '141889702',
#    'vehicleLocation': 'POINT (-122.2012521 47.3931814)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033029406'},
#   {'dataListIndex': '494',
#    'vin': '5YJYGAEE0M',
#    'county': 'King',
#    'city': 'Woodinville',
#    'state': 'WA',
#    'postalCode': '98072',
#    'modelYear': '2021',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '148958365',
#    'vehicleLocation': 'POINT (-122.151665 47.75855)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033021802'},
#   {'dataListIndex': '495',
#    'vin': 'WB523CF01P',
#    'county': 'King',
#    'city': 'Issaquah',
#    'state': 'WA',
#    'postalCode': '98029',
#    'modelYear': '2023',
#    'make': 'BMW',
#    'model': 'IX',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '5',
#    'dolVehicleId': '239713589',
#    'vehicleLocation': 'POINT (-121.999595 47.547635)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032220'},
#   {'dataListIndex': '496',
#    'vin': '3C3CFFGE9H',
#    'county': 'Thurston',
#    'city': 'Olympia',
#    'state': 'WA',
#    'postalCode': '98501',
#    'modelYear': '2017',
#    'make': 'FIAT',
#    'model': '500',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '22',
#    'dolVehicleId': '102382829',
#    'vehicleLocation': 'POINT (-122.89692 47.043535)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067010300'},
#   {'dataListIndex': '497',
#    'vin': '1G1FZ6S0XP',
#    'county': 'Jefferson',
#    'city': 'Port Townsend',
#    'state': 'WA',
#    'postalCode': '98368',
#    'modelYear': '2023',
#    'make': 'CHEVROLET',
#    'model': 'BOLT EUV',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '24',
#    'dolVehicleId': '224737089',
#    'vehicleLocation': 'POINT (-122.7644197 48.1195874)',
#    'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||PUGET SOUND ENERGY INC||PUD NO 1 OF JEFFERSON COUNTY',
#    'CensusTract': '53031950604'},
#   {'dataListIndex': '498',
#    'vin': '5YJYGDEEXM',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98109',
#    'modelYear': '2021',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '36',
#    'dolVehicleId': '135274814',
#    'vehicleLocation': 'POINT (-122.34848 47.632405)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033007002'},
#   {'dataListIndex': '499',
#    'vin': '1N4AZ0CP7F',
#    'county': 'King',
#    'city': 'Shoreline',
#    'state': 'WA',
#    'postalCode': '98155',
#    'modelYear': '2015',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '32',
#    'dolVehicleId': '138211412',
#    'vehicleLocation': 'POINT (-122.3175 47.7578146)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033020500'}],
#  'count': 500,
#  'maxIndex': 300}

# %%
response.status_code

# %%
import pandas as pd

# %%
data = response.json()

# %%
data
# Out:
# {'data': [{'dataListIndex': '0',
#    'vin': 'KM8K33AGXL',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98103',
#    'modelYear': '2020',
#    'make': 'HYUNDAI',
#    'model': 'KONA',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '258',
#    'baseMsrp': '0',
#    'legislativeDistrict': '43',
#    'dolVehicleId': '249675142',
#    'vehicleLocation': 'POINT (-122.34301 47.659185)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033004800'},
#   {'dataListIndex': '1',
#    'vin': '1C4RJYB61N',
#    'county': 'King',
#    'city': 'Bothell',
#    'state': 'WA',
#    'postalCode': '98011',
#    'modelYear': '2022',
#    'make': 'JEEP',
#    'model': 'GRAND CHEROKEE',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '25',
#    'baseMsrp': '0',
#    'legislativeDistrict': '1',
#    'dolVehicleId': '233928502',
#    'vehicleLocation': 'POINT (-122.20578 47.762405)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033021804'},
#   {'dataListIndex': '2',
#    'vin': '1C4RJYD61P',
#    'county': 'Yakima',
#    'city': 'Yakima',
#    'state': 'WA',
#    'postalCode': '98908',
#    'modelYear': '2023',
#    'make': 'JEEP',
#    'model': 'GRAND CHEROKEE',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '25',
#    'baseMsrp': '0',
#    'legislativeDistrict': '14',
#    'dolVehicleId': '229675939',
#    'vehicleLocation': 'POINT (-120.6027202 46.5965625)',
#    'electricUtility': 'PACIFICORP',
#    'CensusTract': '53077002900'},
#   {'dataListIndex': '3',
#    'vin': '5YJ3E1EA7J',
#    'county': 'King',
#    'city': 'Kirkland',
#    'state': 'WA',
#    'postalCode': '98034',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '215',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '104714466',
#    'vehicleLocation': 'POINT (-122.209285 47.71124)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033021903'},
#   {'dataListIndex': '4',
#    'vin': 'WBY7Z8C5XJ',
#    'county': 'Thurston',
#    'city': 'Olympia',
#    'state': 'WA',
#    'postalCode': '98501',
#    'modelYear': '2018',
#    'make': 'BMW',
#    'model': 'I3',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '97',
#    'baseMsrp': '0',
#    'legislativeDistrict': '22',
#    'dolVehicleId': '185498386',
#    'vehicleLocation': 'POINT (-122.89692 47.043535)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067010700'},
#   {'dataListIndex': '5',
#    'vin': '5YJ3E1EAXL',
#    'county': 'Snohomish',
#    'city': 'Marysville',
#    'state': 'WA',
#    'postalCode': '98271',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '266',
#    'baseMsrp': '0',
#    'legislativeDistrict': '38',
#    'dolVehicleId': '124595523',
#    'vehicleLocation': 'POINT (-122.1713847 48.10433)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061940001'},
#   {'dataListIndex': '6',
#    'vin': '2C4RC1N77H',
#    'county': 'King',
#    'city': 'Kent',
#    'state': 'WA',
#    'postalCode': '98042',
#    'modelYear': '2017',
#    'make': 'CHRYSLER',
#    'model': 'PACIFICA',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '33',
#    'baseMsrp': '0',
#    'legislativeDistrict': '47',
#    'dolVehicleId': '1815593',
#    'vehicleLocation': 'POINT (-122.111625 47.36078)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033031707'},
#   {'dataListIndex': '7',
#    'vin': '5YJYGDEE3L',
#    'county': 'King',
#    'city': 'Woodinville',
#    'state': 'WA',
#    'postalCode': '98072',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '291',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '124760555',
#    'vehicleLocation': 'POINT (-122.151665 47.75855)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033021906'},
#   {'dataListIndex': '8',
#    'vin': '5YJ3E1EA1J',
#    'county': 'Island',
#    'city': 'Coupeville',
#    'state': 'WA',
#    'postalCode': '98239',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '215',
#    'baseMsrp': '0',
#    'legislativeDistrict': '10',
#    'dolVehicleId': '125048003',
#    'vehicleLocation': 'POINT (-122.6880708 48.2179983)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53029971000'},
#   {'dataListIndex': '9',
#    'vin': '7SAYGDEF0P',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98004',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '48',
#    'dolVehicleId': '240416207',
#    'vehicleLocation': 'POINT (-122.201905 47.61385)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033023806'},
#   {'dataListIndex': '10',
#    'vin': '5YJ3E1EA7J',
#    'county': 'King',
#    'city': 'Kirkland',
#    'state': 'WA',
#    'postalCode': '98033',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '215',
#    'baseMsrp': '0',
#    'legislativeDistrict': '48',
#    'dolVehicleId': '231013436',
#    'vehicleLocation': 'POINT (-122.20264 47.6785)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033022603'},
#   {'dataListIndex': '11',
#    'vin': '3FA6P0SU9G',
#    'county': 'Kitsap',
#    'city': 'Port Orchard',
#    'state': 'WA',
#    'postalCode': '98367',
#    'modelYear': '2016',
#    'make': 'FORD',
#    'model': 'FUSION',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '19',
#    'baseMsrp': '0',
#    'legislativeDistrict': '26',
#    'dolVehicleId': '212561716',
#    'vehicleLocation': 'POINT (-122.6851642 47.506453)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035092902'},
#   {'dataListIndex': '12',
#    'vin': 'JTDKARFP9H',
#    'county': 'Kitsap',
#    'city': 'Port Orchard',
#    'state': 'WA',
#    'postalCode': '98366',
#    'modelYear': '2017',
#    'make': 'TOYOTA',
#    'model': 'PRIUS PRIME',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '25',
#    'baseMsrp': '0',
#    'legislativeDistrict': '26',
#    'dolVehicleId': '229764972',
#    'vehicleLocation': 'POINT (-122.639265 47.5373)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035092600'},
#   {'dataListIndex': '13',
#    'vin': '5YJ3E1EB8K',
#    'county': 'Snohomish',
#    'city': 'Mukilteo',
#    'state': 'WA',
#    'postalCode': '98275',
#    'modelYear': '2019',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '220',
#    'baseMsrp': '0',
#    'legislativeDistrict': '21',
#    'dolVehicleId': '179728755',
#    'vehicleLocation': 'POINT (-122.299965 47.94171)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061041301'},
#   {'dataListIndex': '14',
#    'vin': '5YJ3E1EA5K',
#    'county': 'King',
#    'city': 'Redmond',
#    'state': 'WA',
#    'postalCode': '98052',
#    'modelYear': '2019',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '220',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '120633516',
#    'vehicleLocation': 'POINT (-122.12302 47.67668)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032323'},
#   {'dataListIndex': '15',
#    'vin': '3FA6P0SU0D',
#    'county': 'Thurston',
#    'city': 'Rochester',
#    'state': 'WA',
#    'postalCode': '98579',
#    'modelYear': '2013',
#    'make': 'FORD',
#    'model': 'FUSION',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '19',
#    'baseMsrp': '0',
#    'legislativeDistrict': '20',
#    'dolVehicleId': '138697212',
#    'vehicleLocation': 'POINT (-123.09573 46.82158)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067012730'},
#   {'dataListIndex': '16',
#    'vin': 'WA1VABGE4K',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98112',
#    'modelYear': '2019',
#    'make': 'AUDI',
#    'model': 'E-TRON',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '204',
#    'baseMsrp': '0',
#    'legislativeDistrict': '43',
#    'dolVehicleId': '475364046',
#    'vehicleLocation': 'POINT (-122.306935 47.62441)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033006400'},
#   {'dataListIndex': '17',
#    'vin': '1N4AZ0CP6F',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98125',
#    'modelYear': '2015',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '46',
#    'dolVehicleId': '252522896',
#    'vehicleLocation': 'POINT (-122.296385 47.71558)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033000201'},
#   {'dataListIndex': '18',
#    'vin': 'KNDCC3LD7K',
#    'county': 'Kitsap',
#    'city': 'Bremerton',
#    'state': 'WA',
#    'postalCode': '98311',
#    'modelYear': '2019',
#    'make': 'KIA',
#    'model': 'NIRO',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '26',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '2148170',
#    'vehicleLocation': 'POINT (-122.6468815 47.6344364)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035091204'},
#   {'dataListIndex': '19',
#    'vin': '1N4AZ0CP1E',
#    'county': 'Kitsap',
#    'city': 'Poulsbo',
#    'state': 'WA',
#    'postalCode': '98370',
#    'modelYear': '2014',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '258176922',
#    'vehicleLocation': 'POINT (-122.64177 47.737525)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035091100'},
#   {'dataListIndex': '20',
#    'vin': '5UXKT0C51J',
#    'county': 'King',
#    'city': 'Kent',
#    'state': 'WA',
#    'postalCode': '98042',
#    'modelYear': '2018',
#    'make': 'BMW',
#    'model': 'X5',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '13',
#    'baseMsrp': '0',
#    'legislativeDistrict': '47',
#    'dolVehicleId': '291897987',
#    'vehicleLocation': 'POINT (-122.111625 47.36078)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033031708'},
#   {'dataListIndex': '21',
#    'vin': '5YJSA1E22J',
#    'county': 'Snohomish',
#    'city': 'Marysville',
#    'state': 'WA',
#    'postalCode': '98271',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL S',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '249',
#    'baseMsrp': '0',
#    'legislativeDistrict': '39',
#    'dolVehicleId': '172808163',
#    'vehicleLocation': 'POINT (-122.1713847 48.10433)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061052808'},
#   {'dataListIndex': '22',
#    'vin': '1G1RB6E46D',
#    'county': 'Kitsap',
#    'city': 'Bremerton',
#    'state': 'WA',
#    'postalCode': '98312',
#    'modelYear': '2013',
#    'make': 'CHEVROLET',
#    'model': 'VOLT',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '38',
#    'baseMsrp': '0',
#    'legislativeDistrict': '35',
#    'dolVehicleId': '138557555',
#    'vehicleLocation': 'POINT (-122.65223 47.57192)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035080700'},
#   {'dataListIndex': '23',
#    'vin': '2T3YL4DV5E',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98108',
#    'modelYear': '2014',
#    'make': 'TOYOTA',
#    'model': 'RAV4',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '103',
#    'baseMsrp': '0',
#    'legislativeDistrict': '11',
#    'dolVehicleId': '183567149',
#    'vehicleLocation': 'POINT (-122.326965 47.55015)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033010001'},
#   {'dataListIndex': '24',
#    'vin': 'JTDKARFP5H',
#    'county': 'Snohomish',
#    'city': 'Lake Stevens',
#    'state': 'WA',
#    'postalCode': '98258',
#    'modelYear': '2017',
#    'make': 'TOYOTA',
#    'model': 'PRIUS PRIME',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '25',
#    'baseMsrp': '0',
#    'legislativeDistrict': '44',
#    'dolVehicleId': '160057901',
#    'vehicleLocation': 'POINT (-122.112265 48.0047)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061052607'},
#   {'dataListIndex': '25',
#    'vin': '5YJ3E1EB6L',
#    'county': 'Kitsap',
#    'city': 'Silverdale',
#    'state': 'WA',
#    'postalCode': '98383',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '322',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '6335647',
#    'vehicleLocation': 'POINT (-122.668076 47.665978)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035091302'},
#   {'dataListIndex': '26',
#    'vin': '5YJ3E1EB3J',
#    'county': 'King',
#    'city': 'Kirkland',
#    'state': 'WA',
#    'postalCode': '98033',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '215',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '205530552',
#    'vehicleLocation': 'POINT (-122.20264 47.6785)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033022401'},
#   {'dataListIndex': '27',
#    'vin': '1FADP5CU0G',
#    'county': 'Kitsap',
#    'city': 'Kingston',
#    'state': 'WA',
#    'postalCode': '98346',
#    'modelYear': '2016',
#    'make': 'FORD',
#    'model': 'C-MAX',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '19',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '1465033',
#    'vehicleLocation': 'POINT (-122.50156 47.8019)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035090102'},
#   {'dataListIndex': '28',
#    'vin': 'WVWKR7AU0K',
#    'county': 'King',
#    'city': 'Kirkland',
#    'state': 'WA',
#    'postalCode': '98033',
#    'modelYear': '2019',
#    'make': 'VOLKSWAGEN',
#    'model': 'E-GOLF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '125',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '306865107',
#    'vehicleLocation': 'POINT (-122.20264 47.6785)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033022006'},
#   {'dataListIndex': '29',
#    'vin': '5YJSA1E29L',
#    'county': 'Kitsap',
#    'city': 'Kingston',
#    'state': 'WA',
#    'postalCode': '98346',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL S',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '330',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '110621444',
#    'vehicleLocation': 'POINT (-122.50156 47.8019)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035090102'},
#   {'dataListIndex': '30',
#    'vin': '1N4AZ0CP7F',
#    'county': 'Thurston',
#    'city': 'Olympia',
#    'state': 'WA',
#    'postalCode': '98506',
#    'modelYear': '2015',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '22',
#    'dolVehicleId': '141547311',
#    'vehicleLocation': 'POINT (-122.8874781 47.0519573)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067010200'},
#   {'dataListIndex': '31',
#    'vin': 'WA1LAAGE7M',
#    'county': 'Yakima',
#    'city': 'Yakima',
#    'state': 'WA',
#    'postalCode': '98908',
#    'modelYear': '2021',
#    'make': 'AUDI',
#    'model': 'E-TRON',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '222',
#    'baseMsrp': '0',
#    'legislativeDistrict': '14',
#    'dolVehicleId': '144941534',
#    'vehicleLocation': 'POINT (-120.6027202 46.5965625)',
#    'electricUtility': 'PACIFICORP',
#    'CensusTract': '53077002801'},
#   {'dataListIndex': '32',
#    'vin': 'KNDCE3LG9K',
#    'county': 'King',
#    'city': 'Enumclaw',
#    'state': 'WA',
#    'postalCode': '98022',
#    'modelYear': '2019',
#    'make': 'KIA',
#    'model': 'NIRO',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '239',
#    'baseMsrp': '0',
#    'legislativeDistrict': '31',
#    'dolVehicleId': '117615928',
#    'vehicleLocation': 'POINT (-121.98953 47.20347)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033031400'},
#   {'dataListIndex': '33',
#    'vin': '1N4AZ0CP9F',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98109',
#    'modelYear': '2015',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '43',
#    'dolVehicleId': '180279487',
#    'vehicleLocation': 'POINT (-122.34848 47.632405)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033007301'},
#   {'dataListIndex': '34',
#    'vin': '5YJ3E1EA4P',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98006',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '241481278',
#    'vehicleLocation': 'POINT (-122.16937 47.571015)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033024704'},
#   {'dataListIndex': '35',
#    'vin': 'JN1AZ0CP1B',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98133',
#    'modelYear': '2011',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '73',
#    'baseMsrp': '0',
#    'legislativeDistrict': '32',
#    'dolVehicleId': '133592196',
#    'vehicleLocation': 'POINT (-122.34584 47.76726)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033000404'},
#   {'dataListIndex': '36',
#    'vin': '3C3CFFGE4G',
#    'county': 'King',
#    'city': 'Auburn',
#    'state': 'WA',
#    'postalCode': '98002',
#    'modelYear': '2016',
#    'make': 'FIAT',
#    'model': '500',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '47',
#    'dolVehicleId': '225708626',
#    'vehicleLocation': 'POINT (-122.222855 47.305065)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033030600'},
#   {'dataListIndex': '37',
#    'vin': '1G1FY6S07L',
#    'county': 'Yakima',
#    'city': 'Moxee',
#    'state': 'WA',
#    'postalCode': '98936',
#    'modelYear': '2020',
#    'make': 'CHEVROLET',
#    'model': 'BOLT EV',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '259',
#    'baseMsrp': '0',
#    'legislativeDistrict': '15',
#    'dolVehicleId': '125943058',
#    'vehicleLocation': 'POINT (-120.3795117 46.55609)',
#    'electricUtility': 'PACIFICORP',
#    'CensusTract': '53077001702'},
#   {'dataListIndex': '38',
#    'vin': '1V2DNPE83P',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98125',
#    'modelYear': '2023',
#    'make': 'VOLKSWAGEN',
#    'model': 'ID.4',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '46',
#    'dolVehicleId': '245619664',
#    'vehicleLocation': 'POINT (-122.296385 47.71558)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033000900'},
#   {'dataListIndex': '39',
#    'vin': '1G1FY6S06N',
#    'county': 'Yakima',
#    'city': 'Tieton',
#    'state': 'WA',
#    'postalCode': '98947',
#    'modelYear': '2022',
#    'make': 'CHEVROLET',
#    'model': 'BOLT EV',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '14',
#    'dolVehicleId': '208932349',
#    'vehicleLocation': 'POINT (-120.75692 46.70383)',
#    'electricUtility': 'PACIFICORP',
#    'CensusTract': '53077002900'},
#   {'dataListIndex': '40',
#    'vin': '1N4AZ0CPXD',
#    'county': 'Kitsap',
#    'city': 'Silverdale',
#    'state': 'WA',
#    'postalCode': '98383',
#    'modelYear': '2013',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '75',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '144485785',
#    'vehicleLocation': 'POINT (-122.668076 47.665978)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035091205'},
#   {'dataListIndex': '41',
#    'vin': '3MW39FS02P',
#    'county': 'Kitsap',
#    'city': 'Port Orchard',
#    'state': 'WA',
#    'postalCode': '98367',
#    'modelYear': '2023',
#    'make': 'BMW',
#    'model': '330E',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '20',
#    'baseMsrp': '0',
#    'legislativeDistrict': '35',
#    'dolVehicleId': '244137120',
#    'vehicleLocation': 'POINT (-122.6851642 47.506453)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035092901'},
#   {'dataListIndex': '42',
#    'vin': '1N4BZ1CP2K',
#    'county': 'King',
#    'city': 'Renton',
#    'state': 'WA',
#    'postalCode': '98057',
#    'modelYear': '2019',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '150',
#    'baseMsrp': '0',
#    'legislativeDistrict': '11',
#    'dolVehicleId': '4870099',
#    'vehicleLocation': 'POINT (-122.21024 47.4797047)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033026200'},
#   {'dataListIndex': '43',
#    'vin': 'WAUTPBFF2H',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98008',
#    'modelYear': '2017',
#    'make': 'AUDI',
#    'model': 'A3',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '16',
#    'baseMsrp': '0',
#    'legislativeDistrict': '48',
#    'dolVehicleId': '159300466',
#    'vehicleLocation': 'POINT (-122.11832 47.6245)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033023300'},
#   {'dataListIndex': '44',
#    'vin': '2C4RC1L73P',
#    'county': 'King',
#    'city': 'Tukwila',
#    'state': 'WA',
#    'postalCode': '98188',
#    'modelYear': '2023',
#    'make': 'CHRYSLER',
#    'model': 'PACIFICA',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '32',
#    'baseMsrp': '0',
#    'legislativeDistrict': '11',
#    'dolVehicleId': '236367519',
#    'vehicleLocation': 'POINT (-122.29179 47.43473)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033028200'},
#   {'dataListIndex': '45',
#    'vin': '5YJ3E1EA7K',
#    'county': 'King',
#    'city': 'Seatac',
#    'state': 'WA',
#    'postalCode': '98188',
#    'modelYear': '2019',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '220',
#    'baseMsrp': '0',
#    'legislativeDistrict': '33',
#    'dolVehicleId': '216597293',
#    'vehicleLocation': 'POINT (-122.29179 47.43473)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033028300'},
#   {'dataListIndex': '46',
#    'vin': '1FADP3R40D',
#    'county': 'Thurston',
#    'city': 'Tumwater',
#    'state': 'WA',
#    'postalCode': '98501',
#    'modelYear': '2013',
#    'make': 'FORD',
#    'model': 'FOCUS',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '76',
#    'baseMsrp': '0',
#    'legislativeDistrict': '35',
#    'dolVehicleId': '230763249',
#    'vehicleLocation': 'POINT (-122.89692 47.043535)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067011720'},
#   {'dataListIndex': '47',
#    'vin': '2C4RC1N79J',
#    'county': 'Kitsap',
#    'city': 'Suquamish',
#    'state': 'WA',
#    'postalCode': '98392',
#    'modelYear': '2018',
#    'make': 'CHRYSLER',
#    'model': 'PACIFICA',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '33',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '176286988',
#    'vehicleLocation': 'POINT (-122.55717 47.733415)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035940100'},
#   {'dataListIndex': '48',
#    'vin': 'KNDRJDLH0N',
#    'county': 'Yakima',
#    'city': 'Yakima',
#    'state': 'WA',
#    'postalCode': '98908',
#    'modelYear': '2022',
#    'make': 'KIA',
#    'model': 'SORENTO',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '32',
#    'baseMsrp': '0',
#    'legislativeDistrict': '14',
#    'dolVehicleId': '209591812',
#    'vehicleLocation': 'POINT (-120.6027202 46.5965625)',
#    'electricUtility': 'PACIFICORP',
#    'CensusTract': '53077000800'},
#   {'dataListIndex': '49',
#    'vin': '3FA6P0SU1H',
#    'county': 'Island',
#    'city': 'Oak Harbor',
#    'state': 'WA',
#    'postalCode': '98277',
#    'modelYear': '2017',
#    'make': 'FORD',
#    'model': 'FUSION',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '21',
#    'baseMsrp': '0',
#    'legislativeDistrict': '10',
#    'dolVehicleId': '250570589',
#    'vehicleLocation': 'POINT (-122.67499 48.287295)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53029970500'},
#   {'dataListIndex': '50',
#    'vin': '5YJ3E1EA8K',
#    'county': 'Snohomish',
#    'city': 'Bothell',
#    'state': 'WA',
#    'postalCode': '98012',
#    'modelYear': '2019',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '220',
#    'baseMsrp': '0',
#    'legislativeDistrict': '1',
#    'dolVehicleId': '338436920',
#    'vehicleLocation': 'POINT (-122.1876761 47.820517)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061052107'},
#   {'dataListIndex': '51',
#    'vin': 'KNDCS3LF7P',
#    'county': 'King',
#    'city': 'Shoreline',
#    'state': 'WA',
#    'postalCode': '98133',
#    'modelYear': '2023',
#    'make': 'KIA',
#    'model': 'NIRO',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '33',
#    'baseMsrp': '0',
#    'legislativeDistrict': '32',
#    'dolVehicleId': '240355930',
#    'vehicleLocation': 'POINT (-122.34584 47.76726)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033020700'},
#   {'dataListIndex': '52',
#    'vin': '5YJ3E1EBXK',
#    'county': 'King',
#    'city': 'Shoreline',
#    'state': 'WA',
#    'postalCode': '98177',
#    'modelYear': '2019',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '220',
#    'baseMsrp': '0',
#    'legislativeDistrict': '32',
#    'dolVehicleId': '310953751',
#    'vehicleLocation': 'POINT (-122.382425 47.77279)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033020100'},
#   {'dataListIndex': '53',
#    'vin': '1G1FZ6S0XL',
#    'county': 'Kitsap',
#    'city': 'Seabeck',
#    'state': 'WA',
#    'postalCode': '98380',
#    'modelYear': '2020',
#    'make': 'CHEVROLET',
#    'model': 'BOLT EV',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '259',
#    'baseMsrp': '0',
#    'legislativeDistrict': '35',
#    'dolVehicleId': '138832844',
#    'vehicleLocation': 'POINT (-122.847462 47.63836)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035092000'},
#   {'dataListIndex': '54',
#    'vin': 'JT3GS10V32',
#    'county': 'King',
#    'city': 'Sammamish',
#    'state': 'WA',
#    'postalCode': '98075',
#    'modelYear': '2002',
#    'make': 'TOYOTA',
#    'model': 'RAV4',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '95',
#    'baseMsrp': '0',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '175935672',
#    'vehicleLocation': 'POINT (-122.03309 47.58153)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032207'},
#   {'dataListIndex': '55',
#    'vin': '5YJ3E1EA1J',
#    'county': 'King',
#    'city': 'Issaquah',
#    'state': 'WA',
#    'postalCode': '98027',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '215',
#    'baseMsrp': '0',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '347726956',
#    'vehicleLocation': 'POINT (-122.03646 47.534065)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033025006'},
#   {'dataListIndex': '56',
#    'vin': 'KM8JFDA26P',
#    'county': 'Snohomish',
#    'city': 'Monroe',
#    'state': 'WA',
#    'postalCode': '98272',
#    'modelYear': '2023',
#    'make': 'HYUNDAI',
#    'model': 'TUCSON',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '33',
#    'baseMsrp': '0',
#    'legislativeDistrict': '39',
#    'dolVehicleId': '252501987',
#    'vehicleLocation': 'POINT (-121.972215 47.85674)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061052203'},
#   {'dataListIndex': '57',
#    'vin': '5YJXCBE41G',
#    'county': 'Kitsap',
#    'city': 'Silverdale',
#    'state': 'WA',
#    'postalCode': '98383',
#    'modelYear': '2016',
#    'make': 'TESLA',
#    'model': 'MODEL X',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '200',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '226085744',
#    'vehicleLocation': 'POINT (-122.668076 47.665978)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035091302'},
#   {'dataListIndex': '58',
#    'vin': 'WBY1Z4C53E',
#    'county': 'Kitsap',
#    'city': 'Bainbridge Island',
#    'state': 'WA',
#    'postalCode': '98110',
#    'modelYear': '2014',
#    'make': 'BMW',
#    'model': 'I3',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '72',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '243689834',
#    'vehicleLocation': 'POINT (-122.5235781 47.6293323)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035091002'},
#   {'dataListIndex': '59',
#    'vin': '1G1FY6S04L',
#    'county': 'King',
#    'city': 'Shoreline',
#    'state': 'WA',
#    'postalCode': '98177',
#    'modelYear': '2020',
#    'make': 'CHEVROLET',
#    'model': 'BOLT EV',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '259',
#    'baseMsrp': '0',
#    'legislativeDistrict': '32',
#    'dolVehicleId': '101572810',
#    'vehicleLocation': 'POINT (-122.382425 47.77279)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033020800'},
#   {'dataListIndex': '60',
#    'vin': 'KNDRJDLH5N',
#    'county': 'Thurston',
#    'city': 'Yelm',
#    'state': 'WA',
#    'postalCode': '98597',
#    'modelYear': '2022',
#    'make': 'KIA',
#    'model': 'SORENTO',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '32',
#    'baseMsrp': '0',
#    'legislativeDistrict': '2',
#    'dolVehicleId': '207310582',
#    'vehicleLocation': 'POINT (-122.61023 46.94126)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067012530'},
#   {'dataListIndex': '61',
#    'vin': 'WBA8E1C50H',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98006',
#    'modelYear': '2017',
#    'make': 'BMW',
#    'model': '330E',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '14',
#    'baseMsrp': '44100',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '477193174',
#    'vehicleLocation': 'POINT (-122.16937 47.571015)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033024901'},
#   {'dataListIndex': '62',
#    'vin': '5YJSA1CPXD',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98112',
#    'modelYear': '2013',
#    'make': 'TESLA',
#    'model': 'MODEL S',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '208',
#    'baseMsrp': '69900',
#    'legislativeDistrict': '43',
#    'dolVehicleId': '103275168',
#    'vehicleLocation': 'POINT (-122.306935 47.62441)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033006300'},
#   {'dataListIndex': '63',
#    'vin': 'JN1AZ0CP5C',
#    'county': 'Snohomish',
#    'city': 'Lake Stevens',
#    'state': 'WA',
#    'postalCode': '98258',
#    'modelYear': '2012',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '73',
#    'baseMsrp': '0',
#    'legislativeDistrict': '44',
#    'dolVehicleId': '165573152',
#    'vehicleLocation': 'POINT (-122.112265 48.0047)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061052607'},
#   {'dataListIndex': '64',
#    'vin': '5YJYGDEE8L',
#    'county': 'Thurston',
#    'city': 'Tumwater',
#    'state': 'WA',
#    'postalCode': '98501',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '291',
#    'baseMsrp': '0',
#    'legislativeDistrict': '35',
#    'dolVehicleId': '124633715',
#    'vehicleLocation': 'POINT (-122.89692 47.043535)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067011720'},
#   {'dataListIndex': '65',
#    'vin': 'JN1AZ0CP1C',
#    'county': 'King',
#    'city': 'Kenmore',
#    'state': 'WA',
#    'postalCode': '98028',
#    'modelYear': '2012',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '73',
#    'baseMsrp': '0',
#    'legislativeDistrict': '46',
#    'dolVehicleId': '158914675',
#    'vehicleLocation': 'POINT (-122.2504747 47.7617128)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033022102'},
#   {'dataListIndex': '66',
#    'vin': '5YJXCDE4XL',
#    'county': 'Thurston',
#    'city': 'Olympia',
#    'state': 'WA',
#    'postalCode': '98502',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL X',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '289',
#    'baseMsrp': '0',
#    'legislativeDistrict': '22',
#    'dolVehicleId': '127274675',
#    'vehicleLocation': 'POINT (-122.92145 47.045935)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067011100'},
#   {'dataListIndex': '67',
#    'vin': '2C4RC1N70L',
#    'county': 'Thurston',
#    'city': 'Olympia',
#    'state': 'WA',
#    'postalCode': '98501',
#    'modelYear': '2020',
#    'make': 'CHRYSLER',
#    'model': 'PACIFICA',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '32',
#    'baseMsrp': '0',
#    'legislativeDistrict': '22',
#    'dolVehicleId': '139479049',
#    'vehicleLocation': 'POINT (-122.89692 47.043535)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067010400'},
#   {'dataListIndex': '68',
#    'vin': 'YV4BR0DM4L',
#    'county': 'King',
#    'city': 'Burien',
#    'state': 'WA',
#    'postalCode': '98166',
#    'modelYear': '2020',
#    'make': 'VOLVO',
#    'model': 'XC60',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '19',
#    'baseMsrp': '0',
#    'legislativeDistrict': '34',
#    'dolVehicleId': '106963650',
#    'vehicleLocation': 'POINT (-122.34102 47.46593)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033027800'},
#   {'dataListIndex': '69',
#    'vin': '1N4AZ0CP9D',
#    'county': 'King',
#    'city': 'Tukwila',
#    'state': 'WA',
#    'postalCode': '98168',
#    'modelYear': '2013',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '75',
#    'baseMsrp': '0',
#    'legislativeDistrict': '11',
#    'dolVehicleId': '164742420',
#    'vehicleLocation': 'POINT (-122.286465 47.476)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033026200'},
#   {'dataListIndex': '70',
#    'vin': '5YJSA1DP8D',
#    'county': 'Snohomish',
#    'city': 'Stanwood',
#    'state': 'WA',
#    'postalCode': '98292',
#    'modelYear': '2013',
#    'make': 'TESLA',
#    'model': 'MODEL S',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '208',
#    'baseMsrp': '69900',
#    'legislativeDistrict': '10',
#    'dolVehicleId': '111162012',
#    'vehicleLocation': 'POINT (-122.3684051 48.2414921)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061053202'},
#   {'dataListIndex': '71',
#    'vin': '1G1RC6S53J',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98109',
#    'modelYear': '2018',
#    'make': 'CHEVROLET',
#    'model': 'VOLT',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '53',
#    'baseMsrp': '0',
#    'legislativeDistrict': '36',
#    'dolVehicleId': '180154600',
#    'vehicleLocation': 'POINT (-122.34848 47.632405)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033006800'},
#   {'dataListIndex': '72',
#    'vin': 'JN1AZ0CP0C',
#    'county': 'King',
#    'city': 'Sammamish',
#    'state': 'WA',
#    'postalCode': '98075',
#    'modelYear': '2012',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '73',
#    'baseMsrp': '0',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '122729736',
#    'vehicleLocation': 'POINT (-122.03309 47.58153)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032213'},
#   {'dataListIndex': '73',
#    'vin': '5YJ3E1EA4P',
#    'county': 'Kitsap',
#    'city': 'Poulsbo',
#    'state': 'WA',
#    'postalCode': '98370',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '233664560',
#    'vehicleLocation': 'POINT (-122.64177 47.737525)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035090502'},
#   {'dataListIndex': '74',
#    'vin': '5YJYGDEE8M',
#    'county': 'Snohomish',
#    'city': 'Arlington',
#    'state': 'WA',
#    'postalCode': '98223',
#    'modelYear': '2021',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '39',
#    'dolVehicleId': '169400570',
#    'vehicleLocation': 'POINT (-122.12324 48.19485)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061053507'},
#   {'dataListIndex': '75',
#    'vin': 'KNDJP3AE1G',
#    'county': 'King',
#    'city': 'Maple Valley',
#    'state': 'WA',
#    'postalCode': '98038',
#    'modelYear': '2016',
#    'make': 'KIA',
#    'model': 'SOUL',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '93',
#    'baseMsrp': '31950',
#    'legislativeDistrict': '5',
#    'dolVehicleId': '263895950',
#    'vehicleLocation': 'POINT (-122.05191 47.357985)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032011'},
#   {'dataListIndex': '76',
#    'vin': 'KNDPZDAH8P',
#    'county': 'Kitsap',
#    'city': 'Poulsbo',
#    'state': 'WA',
#    'postalCode': '98370',
#    'modelYear': '2023',
#    'make': 'KIA',
#    'model': 'SPORTAGE',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '34',
#    'baseMsrp': '0',
#    'legislativeDistrict': '23',
#    'dolVehicleId': '241599438',
#    'vehicleLocation': 'POINT (-122.64177 47.737525)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035090201'},
#   {'dataListIndex': '77',
#    'vin': 'WVGJNPE23N',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98116',
#    'modelYear': '2022',
#    'make': 'VOLKSWAGEN',
#    'model': 'ID.4',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '34',
#    'dolVehicleId': '225909687',
#    'vehicleLocation': 'POINT (-122.38679 47.56484)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033009702'},
#   {'dataListIndex': '78',
#    'vin': '5UXTA6C04N',
#    'county': 'Kitsap',
#    'city': 'Bremerton',
#    'state': 'WA',
#    'postalCode': '98312',
#    'modelYear': '2022',
#    'make': 'BMW',
#    'model': 'X5',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '30',
#    'baseMsrp': '0',
#    'legislativeDistrict': '35',
#    'dolVehicleId': '194341269',
#    'vehicleLocation': 'POINT (-122.65223 47.57192)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035080900'},
#   {'dataListIndex': '79',
#    'vin': '5YJXCDE22J',
#    'county': 'King',
#    'city': 'Medina',
#    'state': 'WA',
#    'postalCode': '98039',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL X',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
# ...
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '161599014',
#    'vehicleLocation': 'POINT (-122.0370611 47.6887161)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032332'},
#   {'dataListIndex': '475',
#    'vin': '1N4BZ1CP0K',
#    'county': 'Whatcom',
#    'city': 'Bellingham',
#    'state': 'WA',
#    'postalCode': '98225',
#    'modelYear': '2019',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '150',
#    'baseMsrp': '0',
#    'legislativeDistrict': '40',
#    'dolVehicleId': '477314127',
#    'vehicleLocation': 'POINT (-122.486115 48.761615)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM COUNTY',
#    'CensusTract': '53073001202'},
#   {'dataListIndex': '476',
#    'vin': '1N4AZ0CP6E',
#    'county': 'Snohomish',
#    'city': 'Marysville',
#    'state': 'WA',
#    'postalCode': '98270',
#    'modelYear': '2014',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '38',
#    'dolVehicleId': '289423739',
#    'vehicleLocation': 'POINT (-122.17673 48.05542)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53061052904'},
#   {'dataListIndex': '477',
#    'vin': '5YJ3E1EA5P',
#    'county': 'King',
#    'city': 'Issaquah',
#    'state': 'WA',
#    'postalCode': '98029',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '5',
#    'dolVehicleId': '239781069',
#    'vehicleLocation': 'POINT (-121.999595 47.547635)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032220'},
#   {'dataListIndex': '478',
#    'vin': '5YJ3E1EA2L',
#    'county': 'Kitsap',
#    'city': 'Port Orchard',
#    'state': 'WA',
#    'postalCode': '98366',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '266',
#    'baseMsrp': '0',
#    'legislativeDistrict': '26',
#    'dolVehicleId': '6249078',
#    'vehicleLocation': 'POINT (-122.639265 47.5373)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53035092600'},
#   {'dataListIndex': '479',
#    'vin': '5YJ3E1EB5P',
#    'county': 'King',
#    'city': 'Shoreline',
#    'state': 'WA',
#    'postalCode': '98177',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '32',
#    'dolVehicleId': '245715844',
#    'vehicleLocation': 'POINT (-122.382425 47.77279)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033020800'},
#   {'dataListIndex': '480',
#    'vin': '7SAYGDEE2P',
#    'county': 'Clark',
#    'city': 'La Center',
#    'state': 'WA',
#    'postalCode': '98629',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '18',
#    'dolVehicleId': '251668329',
#    'vehicleLocation': 'POINT (-122.6706246 45.8662548)',
#    'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)',
#    'CensusTract': '53011040201'},
#   {'dataListIndex': '481',
#    'vin': 'YV4BR0CL6K',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98177',
#    'modelYear': '2019',
#    'make': 'VOLVO',
#    'model': 'XC90',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '17',
#    'baseMsrp': '0',
#    'legislativeDistrict': '36',
#    'dolVehicleId': '326903881',
#    'vehicleLocation': 'POINT (-122.382425 47.77279)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033001600'},
#   {'dataListIndex': '482',
#    'vin': '5YJSA1E26J',
#    'county': 'Pierce',
#    'city': 'Lakewood',
#    'state': 'WA',
#    'postalCode': '98498',
#    'modelYear': '2018',
#    'make': 'TESLA',
#    'model': 'MODEL S',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '249',
#    'baseMsrp': '0',
#    'legislativeDistrict': '28',
#    'dolVehicleId': '131349165',
#    'vehicleLocation': 'POINT (-122.547645 47.176685)',
#    'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY',
#    'CensusTract': '53053072106'},
#   {'dataListIndex': '483',
#    'vin': 'JTMABABA9P',
#    'county': 'King',
#    'city': 'Tukwila',
#    'state': 'WA',
#    'postalCode': '98188',
#    'modelYear': '2023',
#    'make': 'SUBARU',
#    'model': 'SOLTERRA',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '11',
#    'dolVehicleId': '252339734',
#    'vehicleLocation': 'POINT (-122.29179 47.43473)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033028200'},
#   {'dataListIndex': '484',
#    'vin': '5YJXCAE2XL',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98008',
#    'modelYear': '2020',
#    'make': 'TESLA',
#    'model': 'MODEL X',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '293',
#    'baseMsrp': '0',
#    'legislativeDistrict': '48',
#    'dolVehicleId': '2096342',
#    'vehicleLocation': 'POINT (-122.11832 47.6245)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033023100'},
#   {'dataListIndex': '485',
#    'vin': '1N4BZ0CP6H',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98006',
#    'modelYear': '2017',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '107',
#    'baseMsrp': '0',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '348003407',
#    'vehicleLocation': 'POINT (-122.16937 47.571015)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033024905'},
#   {'dataListIndex': '486',
#    'vin': '7SAYGDEE4P',
#    'county': 'King',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'postalCode': '98005',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '41',
#    'dolVehicleId': '232642511',
#    'vehicleLocation': 'POINT (-122.16085 47.624515)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033023601'},
#   {'dataListIndex': '487',
#    'vin': 'WAUSPBFF1H',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98102',
#    'modelYear': '2017',
#    'make': 'AUDI',
#    'model': 'A3',
#    'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#    'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#    'electricRange': '16',
#    'baseMsrp': '0',
#    'legislativeDistrict': '43',
#    'dolVehicleId': '135207054',
#    'vehicleLocation': 'POINT (-122.3223156 47.6402108)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033007501'},
#   {'dataListIndex': '488',
#    'vin': '7SAYGDEE0P',
#    'county': 'King',
#    'city': 'Woodinville',
#    'state': 'WA',
#    'postalCode': '98072',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '230807286',
#    'vehicleLocation': 'POINT (-122.151665 47.75855)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033021906'},
#   {'dataListIndex': '489',
#    'vin': '1N4BZ1CP4K',
#    'county': 'Clark',
#    'city': 'Vancouver',
#    'state': 'WA',
#    'postalCode': '98682',
#    'modelYear': '2019',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '150',
#    'baseMsrp': '0',
#    'legislativeDistrict': '17',
#    'dolVehicleId': '106928818',
#    'vehicleLocation': 'POINT (-122.5146473 45.67862)',
#    'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)',
#    'CensusTract': '53011040713'},
#   {'dataListIndex': '490',
#    'vin': '5YJ3E1EB0M',
#    'county': 'King',
#    'city': 'Woodinville',
#    'state': 'WA',
#    'postalCode': '98072',
#    'modelYear': '2021',
#    'make': 'TESLA',
#    'model': 'MODEL 3',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '161665864',
#    'vehicleLocation': 'POINT (-122.151665 47.75855)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033021802'},
#   {'dataListIndex': '491',
#    'vin': '7SAYGDEE3P',
#    'county': 'Clark',
#    'city': 'Brush Prairie',
#    'state': 'WA',
#    'postalCode': '98606',
#    'modelYear': '2023',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '17',
#    'dolVehicleId': '223894352',
#    'vehicleLocation': 'POINT (-122.5485715 45.7336587)',
#    'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)',
#    'CensusTract': '53011040715'},
#   {'dataListIndex': '492',
#    'vin': '1V25MPE80P',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98103',
#    'modelYear': '2023',
#    'make': 'VOLKSWAGEN',
#    'model': 'ID.4',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '43',
#    'dolVehicleId': '240635825',
#    'vehicleLocation': 'POINT (-122.34301 47.659185)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033005000'},
#   {'dataListIndex': '493',
#    'vin': '5YJXCBE45H',
#    'county': 'King',
#    'city': 'Kent',
#    'state': 'WA',
#    'postalCode': '98031',
#    'modelYear': '2017',
#    'make': 'TESLA',
#    'model': 'MODEL X',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '200',
#    'baseMsrp': '0',
#    'legislativeDistrict': '47',
#    'dolVehicleId': '141889702',
#    'vehicleLocation': 'POINT (-122.2012521 47.3931814)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033029406'},
#   {'dataListIndex': '494',
#    'vin': '5YJYGAEE0M',
#    'county': 'King',
#    'city': 'Woodinville',
#    'state': 'WA',
#    'postalCode': '98072',
#    'modelYear': '2021',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '45',
#    'dolVehicleId': '148958365',
#    'vehicleLocation': 'POINT (-122.151665 47.75855)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033021802'},
#   {'dataListIndex': '495',
#    'vin': 'WB523CF01P',
#    'county': 'King',
#    'city': 'Issaquah',
#    'state': 'WA',
#    'postalCode': '98029',
#    'modelYear': '2023',
#    'make': 'BMW',
#    'model': 'IX',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '5',
#    'dolVehicleId': '239713589',
#    'vehicleLocation': 'POINT (-121.999595 47.547635)',
#    'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#    'CensusTract': '53033032220'},
#   {'dataListIndex': '496',
#    'vin': '3C3CFFGE9H',
#    'county': 'Thurston',
#    'city': 'Olympia',
#    'state': 'WA',
#    'postalCode': '98501',
#    'modelYear': '2017',
#    'make': 'FIAT',
#    'model': '500',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '22',
#    'dolVehicleId': '102382829',
#    'vehicleLocation': 'POINT (-122.89692 47.043535)',
#    'electricUtility': 'PUGET SOUND ENERGY INC',
#    'CensusTract': '53067010300'},
#   {'dataListIndex': '497',
#    'vin': '1G1FZ6S0XP',
#    'county': 'Jefferson',
#    'city': 'Port Townsend',
#    'state': 'WA',
#    'postalCode': '98368',
#    'modelYear': '2023',
#    'make': 'CHEVROLET',
#    'model': 'BOLT EUV',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '24',
#    'dolVehicleId': '224737089',
#    'vehicleLocation': 'POINT (-122.7644197 48.1195874)',
#    'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||PUGET SOUND ENERGY INC||PUD NO 1 OF JEFFERSON COUNTY',
#    'CensusTract': '53031950604'},
#   {'dataListIndex': '498',
#    'vin': '5YJYGDEEXM',
#    'county': 'King',
#    'city': 'Seattle',
#    'state': 'WA',
#    'postalCode': '98109',
#    'modelYear': '2021',
#    'make': 'TESLA',
#    'model': 'MODEL Y',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#    'electricRange': '0',
#    'baseMsrp': '0',
#    'legislativeDistrict': '36',
#    'dolVehicleId': '135274814',
#    'vehicleLocation': 'POINT (-122.34848 47.632405)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033007002'},
#   {'dataListIndex': '499',
#    'vin': '1N4AZ0CP7F',
#    'county': 'King',
#    'city': 'Shoreline',
#    'state': 'WA',
#    'postalCode': '98155',
#    'modelYear': '2015',
#    'make': 'NISSAN',
#    'model': 'LEAF',
#    'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#    'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#    'electricRange': '84',
#    'baseMsrp': '0',
#    'legislativeDistrict': '32',
#    'dolVehicleId': '138211412',
#    'vehicleLocation': 'POINT (-122.3175 47.7578146)',
#    'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#    'CensusTract': '53033020500'}],
#  'count': 500,
#  'maxIndex': 300}

# %%
data_1 = data["data"]
data_1
# Out:
# [{'dataListIndex': '0',
#   'vin': 'KM8K33AGXL',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98103',
#   'modelYear': '2020',
#   'make': 'HYUNDAI',
#   'model': 'KONA',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '258',
#   'baseMsrp': '0',
#   'legislativeDistrict': '43',
#   'dolVehicleId': '249675142',
#   'vehicleLocation': 'POINT (-122.34301 47.659185)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033004800'},
#  {'dataListIndex': '1',
#   'vin': '1C4RJYB61N',
#   'county': 'King',
#   'city': 'Bothell',
#   'state': 'WA',
#   'postalCode': '98011',
#   'modelYear': '2022',
#   'make': 'JEEP',
#   'model': 'GRAND CHEROKEE',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '25',
#   'baseMsrp': '0',
#   'legislativeDistrict': '1',
#   'dolVehicleId': '233928502',
#   'vehicleLocation': 'POINT (-122.20578 47.762405)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033021804'},
#  {'dataListIndex': '2',
#   'vin': '1C4RJYD61P',
#   'county': 'Yakima',
#   'city': 'Yakima',
#   'state': 'WA',
#   'postalCode': '98908',
#   'modelYear': '2023',
#   'make': 'JEEP',
#   'model': 'GRAND CHEROKEE',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '25',
#   'baseMsrp': '0',
#   'legislativeDistrict': '14',
#   'dolVehicleId': '229675939',
#   'vehicleLocation': 'POINT (-120.6027202 46.5965625)',
#   'electricUtility': 'PACIFICORP',
#   'CensusTract': '53077002900'},
#  {'dataListIndex': '3',
#   'vin': '5YJ3E1EA7J',
#   'county': 'King',
#   'city': 'Kirkland',
#   'state': 'WA',
#   'postalCode': '98034',
#   'modelYear': '2018',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '215',
#   'baseMsrp': '0',
#   'legislativeDistrict': '45',
#   'dolVehicleId': '104714466',
#   'vehicleLocation': 'POINT (-122.209285 47.71124)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033021903'},
#  {'dataListIndex': '4',
#   'vin': 'WBY7Z8C5XJ',
#   'county': 'Thurston',
#   'city': 'Olympia',
#   'state': 'WA',
#   'postalCode': '98501',
#   'modelYear': '2018',
#   'make': 'BMW',
#   'model': 'I3',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '97',
#   'baseMsrp': '0',
#   'legislativeDistrict': '22',
#   'dolVehicleId': '185498386',
#   'vehicleLocation': 'POINT (-122.89692 47.043535)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53067010700'},
#  {'dataListIndex': '5',
#   'vin': '5YJ3E1EAXL',
#   'county': 'Snohomish',
#   'city': 'Marysville',
#   'state': 'WA',
#   'postalCode': '98271',
#   'modelYear': '2020',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '266',
#   'baseMsrp': '0',
#   'legislativeDistrict': '38',
#   'dolVehicleId': '124595523',
#   'vehicleLocation': 'POINT (-122.1713847 48.10433)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53061940001'},
#  {'dataListIndex': '6',
#   'vin': '2C4RC1N77H',
#   'county': 'King',
#   'city': 'Kent',
#   'state': 'WA',
#   'postalCode': '98042',
#   'modelYear': '2017',
#   'make': 'CHRYSLER',
#   'model': 'PACIFICA',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '33',
#   'baseMsrp': '0',
#   'legislativeDistrict': '47',
#   'dolVehicleId': '1815593',
#   'vehicleLocation': 'POINT (-122.111625 47.36078)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033031707'},
#  {'dataListIndex': '7',
#   'vin': '5YJYGDEE3L',
#   'county': 'King',
#   'city': 'Woodinville',
#   'state': 'WA',
#   'postalCode': '98072',
#   'modelYear': '2020',
#   'make': 'TESLA',
#   'model': 'MODEL Y',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '291',
#   'baseMsrp': '0',
#   'legislativeDistrict': '45',
#   'dolVehicleId': '124760555',
#   'vehicleLocation': 'POINT (-122.151665 47.75855)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033021906'},
#  {'dataListIndex': '8',
#   'vin': '5YJ3E1EA1J',
#   'county': 'Island',
#   'city': 'Coupeville',
#   'state': 'WA',
#   'postalCode': '98239',
#   'modelYear': '2018',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '215',
#   'baseMsrp': '0',
#   'legislativeDistrict': '10',
#   'dolVehicleId': '125048003',
#   'vehicleLocation': 'POINT (-122.6880708 48.2179983)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53029971000'},
#  {'dataListIndex': '9',
#   'vin': '7SAYGDEF0P',
#   'county': 'King',
#   'city': 'Bellevue',
#   'state': 'WA',
#   'postalCode': '98004',
#   'modelYear': '2023',
#   'make': 'TESLA',
#   'model': 'MODEL Y',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '48',
#   'dolVehicleId': '240416207',
#   'vehicleLocation': 'POINT (-122.201905 47.61385)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033023806'},
#  {'dataListIndex': '10',
#   'vin': '5YJ3E1EA7J',
#   'county': 'King',
#   'city': 'Kirkland',
#   'state': 'WA',
#   'postalCode': '98033',
#   'modelYear': '2018',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '215',
#   'baseMsrp': '0',
#   'legislativeDistrict': '48',
#   'dolVehicleId': '231013436',
#   'vehicleLocation': 'POINT (-122.20264 47.6785)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033022603'},
#  {'dataListIndex': '11',
#   'vin': '3FA6P0SU9G',
#   'county': 'Kitsap',
#   'city': 'Port Orchard',
#   'state': 'WA',
#   'postalCode': '98367',
#   'modelYear': '2016',
#   'make': 'FORD',
#   'model': 'FUSION',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '19',
#   'baseMsrp': '0',
#   'legislativeDistrict': '26',
#   'dolVehicleId': '212561716',
#   'vehicleLocation': 'POINT (-122.6851642 47.506453)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035092902'},
#  {'dataListIndex': '12',
#   'vin': 'JTDKARFP9H',
#   'county': 'Kitsap',
#   'city': 'Port Orchard',
#   'state': 'WA',
#   'postalCode': '98366',
#   'modelYear': '2017',
#   'make': 'TOYOTA',
#   'model': 'PRIUS PRIME',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '25',
#   'baseMsrp': '0',
#   'legislativeDistrict': '26',
#   'dolVehicleId': '229764972',
#   'vehicleLocation': 'POINT (-122.639265 47.5373)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035092600'},
#  {'dataListIndex': '13',
#   'vin': '5YJ3E1EB8K',
#   'county': 'Snohomish',
#   'city': 'Mukilteo',
#   'state': 'WA',
#   'postalCode': '98275',
#   'modelYear': '2019',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '220',
#   'baseMsrp': '0',
#   'legislativeDistrict': '21',
#   'dolVehicleId': '179728755',
#   'vehicleLocation': 'POINT (-122.299965 47.94171)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53061041301'},
#  {'dataListIndex': '14',
#   'vin': '5YJ3E1EA5K',
#   'county': 'King',
#   'city': 'Redmond',
#   'state': 'WA',
#   'postalCode': '98052',
#   'modelYear': '2019',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '220',
#   'baseMsrp': '0',
#   'legislativeDistrict': '45',
#   'dolVehicleId': '120633516',
#   'vehicleLocation': 'POINT (-122.12302 47.67668)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033032323'},
#  {'dataListIndex': '15',
#   'vin': '3FA6P0SU0D',
#   'county': 'Thurston',
#   'city': 'Rochester',
#   'state': 'WA',
#   'postalCode': '98579',
#   'modelYear': '2013',
#   'make': 'FORD',
#   'model': 'FUSION',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '19',
#   'baseMsrp': '0',
#   'legislativeDistrict': '20',
#   'dolVehicleId': '138697212',
#   'vehicleLocation': 'POINT (-123.09573 46.82158)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53067012730'},
#  {'dataListIndex': '16',
#   'vin': 'WA1VABGE4K',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98112',
#   'modelYear': '2019',
#   'make': 'AUDI',
#   'model': 'E-TRON',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '204',
#   'baseMsrp': '0',
#   'legislativeDistrict': '43',
#   'dolVehicleId': '475364046',
#   'vehicleLocation': 'POINT (-122.306935 47.62441)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033006400'},
#  {'dataListIndex': '17',
#   'vin': '1N4AZ0CP6F',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98125',
#   'modelYear': '2015',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '84',
#   'baseMsrp': '0',
#   'legislativeDistrict': '46',
#   'dolVehicleId': '252522896',
#   'vehicleLocation': 'POINT (-122.296385 47.71558)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033000201'},
#  {'dataListIndex': '18',
#   'vin': 'KNDCC3LD7K',
#   'county': 'Kitsap',
#   'city': 'Bremerton',
#   'state': 'WA',
#   'postalCode': '98311',
#   'modelYear': '2019',
#   'make': 'KIA',
#   'model': 'NIRO',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '26',
#   'baseMsrp': '0',
#   'legislativeDistrict': '23',
#   'dolVehicleId': '2148170',
#   'vehicleLocation': 'POINT (-122.6468815 47.6344364)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035091204'},
#  {'dataListIndex': '19',
#   'vin': '1N4AZ0CP1E',
#   'county': 'Kitsap',
#   'city': 'Poulsbo',
#   'state': 'WA',
#   'postalCode': '98370',
#   'modelYear': '2014',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '84',
#   'baseMsrp': '0',
#   'legislativeDistrict': '23',
#   'dolVehicleId': '258176922',
#   'vehicleLocation': 'POINT (-122.64177 47.737525)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035091100'},
#  {'dataListIndex': '20',
#   'vin': '5UXKT0C51J',
#   'county': 'King',
#   'city': 'Kent',
#   'state': 'WA',
#   'postalCode': '98042',
#   'modelYear': '2018',
#   'make': 'BMW',
#   'model': 'X5',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '13',
#   'baseMsrp': '0',
#   'legislativeDistrict': '47',
#   'dolVehicleId': '291897987',
#   'vehicleLocation': 'POINT (-122.111625 47.36078)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033031708'},
#  {'dataListIndex': '21',
#   'vin': '5YJSA1E22J',
#   'county': 'Snohomish',
#   'city': 'Marysville',
#   'state': 'WA',
#   'postalCode': '98271',
#   'modelYear': '2018',
#   'make': 'TESLA',
#   'model': 'MODEL S',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '249',
#   'baseMsrp': '0',
#   'legislativeDistrict': '39',
#   'dolVehicleId': '172808163',
#   'vehicleLocation': 'POINT (-122.1713847 48.10433)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53061052808'},
#  {'dataListIndex': '22',
#   'vin': '1G1RB6E46D',
#   'county': 'Kitsap',
#   'city': 'Bremerton',
#   'state': 'WA',
#   'postalCode': '98312',
#   'modelYear': '2013',
#   'make': 'CHEVROLET',
#   'model': 'VOLT',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '38',
#   'baseMsrp': '0',
#   'legislativeDistrict': '35',
#   'dolVehicleId': '138557555',
#   'vehicleLocation': 'POINT (-122.65223 47.57192)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035080700'},
#  {'dataListIndex': '23',
#   'vin': '2T3YL4DV5E',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98108',
#   'modelYear': '2014',
#   'make': 'TOYOTA',
#   'model': 'RAV4',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '103',
#   'baseMsrp': '0',
#   'legislativeDistrict': '11',
#   'dolVehicleId': '183567149',
#   'vehicleLocation': 'POINT (-122.326965 47.55015)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033010001'},
#  {'dataListIndex': '24',
#   'vin': 'JTDKARFP5H',
#   'county': 'Snohomish',
#   'city': 'Lake Stevens',
#   'state': 'WA',
#   'postalCode': '98258',
#   'modelYear': '2017',
#   'make': 'TOYOTA',
#   'model': 'PRIUS PRIME',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '25',
#   'baseMsrp': '0',
#   'legislativeDistrict': '44',
#   'dolVehicleId': '160057901',
#   'vehicleLocation': 'POINT (-122.112265 48.0047)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53061052607'},
#  {'dataListIndex': '25',
#   'vin': '5YJ3E1EB6L',
#   'county': 'Kitsap',
#   'city': 'Silverdale',
#   'state': 'WA',
#   'postalCode': '98383',
#   'modelYear': '2020',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '322',
#   'baseMsrp': '0',
#   'legislativeDistrict': '23',
#   'dolVehicleId': '6335647',
#   'vehicleLocation': 'POINT (-122.668076 47.665978)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035091302'},
#  {'dataListIndex': '26',
#   'vin': '5YJ3E1EB3J',
#   'county': 'King',
#   'city': 'Kirkland',
#   'state': 'WA',
#   'postalCode': '98033',
#   'modelYear': '2018',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '215',
#   'baseMsrp': '0',
#   'legislativeDistrict': '45',
#   'dolVehicleId': '205530552',
#   'vehicleLocation': 'POINT (-122.20264 47.6785)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033022401'},
#  {'dataListIndex': '27',
#   'vin': '1FADP5CU0G',
#   'county': 'Kitsap',
#   'city': 'Kingston',
#   'state': 'WA',
#   'postalCode': '98346',
#   'modelYear': '2016',
#   'make': 'FORD',
#   'model': 'C-MAX',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '19',
#   'baseMsrp': '0',
#   'legislativeDistrict': '23',
#   'dolVehicleId': '1465033',
#   'vehicleLocation': 'POINT (-122.50156 47.8019)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035090102'},
#  {'dataListIndex': '28',
#   'vin': 'WVWKR7AU0K',
#   'county': 'King',
#   'city': 'Kirkland',
#   'state': 'WA',
#   'postalCode': '98033',
#   'modelYear': '2019',
#   'make': 'VOLKSWAGEN',
#   'model': 'E-GOLF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '125',
#   'baseMsrp': '0',
#   'legislativeDistrict': '45',
#   'dolVehicleId': '306865107',
#   'vehicleLocation': 'POINT (-122.20264 47.6785)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033022006'},
#  {'dataListIndex': '29',
#   'vin': '5YJSA1E29L',
#   'county': 'Kitsap',
#   'city': 'Kingston',
#   'state': 'WA',
#   'postalCode': '98346',
#   'modelYear': '2020',
#   'make': 'TESLA',
#   'model': 'MODEL S',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '330',
#   'baseMsrp': '0',
#   'legislativeDistrict': '23',
#   'dolVehicleId': '110621444',
#   'vehicleLocation': 'POINT (-122.50156 47.8019)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035090102'},
#  {'dataListIndex': '30',
#   'vin': '1N4AZ0CP7F',
#   'county': 'Thurston',
#   'city': 'Olympia',
#   'state': 'WA',
#   'postalCode': '98506',
#   'modelYear': '2015',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '84',
#   'baseMsrp': '0',
#   'legislativeDistrict': '22',
#   'dolVehicleId': '141547311',
#   'vehicleLocation': 'POINT (-122.8874781 47.0519573)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53067010200'},
#  {'dataListIndex': '31',
#   'vin': 'WA1LAAGE7M',
#   'county': 'Yakima',
#   'city': 'Yakima',
#   'state': 'WA',
#   'postalCode': '98908',
#   'modelYear': '2021',
#   'make': 'AUDI',
#   'model': 'E-TRON',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '222',
#   'baseMsrp': '0',
#   'legislativeDistrict': '14',
#   'dolVehicleId': '144941534',
#   'vehicleLocation': 'POINT (-120.6027202 46.5965625)',
#   'electricUtility': 'PACIFICORP',
#   'CensusTract': '53077002801'},
#  {'dataListIndex': '32',
#   'vin': 'KNDCE3LG9K',
#   'county': 'King',
#   'city': 'Enumclaw',
#   'state': 'WA',
#   'postalCode': '98022',
#   'modelYear': '2019',
#   'make': 'KIA',
#   'model': 'NIRO',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '239',
#   'baseMsrp': '0',
#   'legislativeDistrict': '31',
#   'dolVehicleId': '117615928',
#   'vehicleLocation': 'POINT (-121.98953 47.20347)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033031400'},
#  {'dataListIndex': '33',
#   'vin': '1N4AZ0CP9F',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98109',
#   'modelYear': '2015',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '84',
#   'baseMsrp': '0',
#   'legislativeDistrict': '43',
#   'dolVehicleId': '180279487',
#   'vehicleLocation': 'POINT (-122.34848 47.632405)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033007301'},
#  {'dataListIndex': '34',
#   'vin': '5YJ3E1EA4P',
#   'county': 'King',
#   'city': 'Bellevue',
#   'state': 'WA',
#   'postalCode': '98006',
#   'modelYear': '2023',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '41',
#   'dolVehicleId': '241481278',
#   'vehicleLocation': 'POINT (-122.16937 47.571015)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033024704'},
#  {'dataListIndex': '35',
#   'vin': 'JN1AZ0CP1B',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98133',
#   'modelYear': '2011',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '73',
#   'baseMsrp': '0',
#   'legislativeDistrict': '32',
#   'dolVehicleId': '133592196',
#   'vehicleLocation': 'POINT (-122.34584 47.76726)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033000404'},
#  {'dataListIndex': '36',
#   'vin': '3C3CFFGE4G',
#   'county': 'King',
#   'city': 'Auburn',
#   'state': 'WA',
#   'postalCode': '98002',
#   'modelYear': '2016',
#   'make': 'FIAT',
#   'model': '500',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '84',
#   'baseMsrp': '0',
#   'legislativeDistrict': '47',
#   'dolVehicleId': '225708626',
#   'vehicleLocation': 'POINT (-122.222855 47.305065)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033030600'},
#  {'dataListIndex': '37',
#   'vin': '1G1FY6S07L',
#   'county': 'Yakima',
#   'city': 'Moxee',
#   'state': 'WA',
#   'postalCode': '98936',
#   'modelYear': '2020',
#   'make': 'CHEVROLET',
#   'model': 'BOLT EV',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '259',
#   'baseMsrp': '0',
#   'legislativeDistrict': '15',
#   'dolVehicleId': '125943058',
#   'vehicleLocation': 'POINT (-120.3795117 46.55609)',
#   'electricUtility': 'PACIFICORP',
#   'CensusTract': '53077001702'},
#  {'dataListIndex': '38',
#   'vin': '1V2DNPE83P',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98125',
#   'modelYear': '2023',
#   'make': 'VOLKSWAGEN',
#   'model': 'ID.4',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '46',
#   'dolVehicleId': '245619664',
#   'vehicleLocation': 'POINT (-122.296385 47.71558)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033000900'},
#  {'dataListIndex': '39',
#   'vin': '1G1FY6S06N',
#   'county': 'Yakima',
#   'city': 'Tieton',
#   'state': 'WA',
#   'postalCode': '98947',
#   'modelYear': '2022',
#   'make': 'CHEVROLET',
#   'model': 'BOLT EV',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '14',
#   'dolVehicleId': '208932349',
#   'vehicleLocation': 'POINT (-120.75692 46.70383)',
#   'electricUtility': 'PACIFICORP',
#   'CensusTract': '53077002900'},
#  {'dataListIndex': '40',
#   'vin': '1N4AZ0CPXD',
#   'county': 'Kitsap',
#   'city': 'Silverdale',
#   'state': 'WA',
#   'postalCode': '98383',
#   'modelYear': '2013',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '75',
#   'baseMsrp': '0',
#   'legislativeDistrict': '23',
#   'dolVehicleId': '144485785',
#   'vehicleLocation': 'POINT (-122.668076 47.665978)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035091205'},
#  {'dataListIndex': '41',
#   'vin': '3MW39FS02P',
#   'county': 'Kitsap',
#   'city': 'Port Orchard',
#   'state': 'WA',
#   'postalCode': '98367',
#   'modelYear': '2023',
#   'make': 'BMW',
#   'model': '330E',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '20',
#   'baseMsrp': '0',
#   'legislativeDistrict': '35',
#   'dolVehicleId': '244137120',
#   'vehicleLocation': 'POINT (-122.6851642 47.506453)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035092901'},
#  {'dataListIndex': '42',
#   'vin': '1N4BZ1CP2K',
#   'county': 'King',
#   'city': 'Renton',
#   'state': 'WA',
#   'postalCode': '98057',
#   'modelYear': '2019',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '150',
#   'baseMsrp': '0',
#   'legislativeDistrict': '11',
#   'dolVehicleId': '4870099',
#   'vehicleLocation': 'POINT (-122.21024 47.4797047)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033026200'},
#  {'dataListIndex': '43',
#   'vin': 'WAUTPBFF2H',
#   'county': 'King',
#   'city': 'Bellevue',
#   'state': 'WA',
#   'postalCode': '98008',
#   'modelYear': '2017',
#   'make': 'AUDI',
#   'model': 'A3',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '16',
#   'baseMsrp': '0',
#   'legislativeDistrict': '48',
#   'dolVehicleId': '159300466',
#   'vehicleLocation': 'POINT (-122.11832 47.6245)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033023300'},
#  {'dataListIndex': '44',
#   'vin': '2C4RC1L73P',
#   'county': 'King',
#   'city': 'Tukwila',
#   'state': 'WA',
#   'postalCode': '98188',
#   'modelYear': '2023',
#   'make': 'CHRYSLER',
#   'model': 'PACIFICA',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '32',
#   'baseMsrp': '0',
#   'legislativeDistrict': '11',
#   'dolVehicleId': '236367519',
#   'vehicleLocation': 'POINT (-122.29179 47.43473)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033028200'},
#  {'dataListIndex': '45',
#   'vin': '5YJ3E1EA7K',
#   'county': 'King',
#   'city': 'Seatac',
#   'state': 'WA',
#   'postalCode': '98188',
#   'modelYear': '2019',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '220',
#   'baseMsrp': '0',
#   'legislativeDistrict': '33',
#   'dolVehicleId': '216597293',
#   'vehicleLocation': 'POINT (-122.29179 47.43473)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033028300'},
#  {'dataListIndex': '46',
#   'vin': '1FADP3R40D',
#   'county': 'Thurston',
#   'city': 'Tumwater',
#   'state': 'WA',
#   'postalCode': '98501',
#   'modelYear': '2013',
#   'make': 'FORD',
#   'model': 'FOCUS',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '76',
#   'baseMsrp': '0',
#   'legislativeDistrict': '35',
#   'dolVehicleId': '230763249',
#   'vehicleLocation': 'POINT (-122.89692 47.043535)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53067011720'},
#  {'dataListIndex': '47',
#   'vin': '2C4RC1N79J',
#   'county': 'Kitsap',
#   'city': 'Suquamish',
#   'state': 'WA',
#   'postalCode': '98392',
#   'modelYear': '2018',
#   'make': 'CHRYSLER',
#   'model': 'PACIFICA',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '33',
#   'baseMsrp': '0',
#   'legislativeDistrict': '23',
#   'dolVehicleId': '176286988',
#   'vehicleLocation': 'POINT (-122.55717 47.733415)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035940100'},
#  {'dataListIndex': '48',
#   'vin': 'KNDRJDLH0N',
#   'county': 'Yakima',
#   'city': 'Yakima',
#   'state': 'WA',
#   'postalCode': '98908',
#   'modelYear': '2022',
#   'make': 'KIA',
#   'model': 'SORENTO',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '32',
#   'baseMsrp': '0',
#   'legislativeDistrict': '14',
#   'dolVehicleId': '209591812',
#   'vehicleLocation': 'POINT (-120.6027202 46.5965625)',
#   'electricUtility': 'PACIFICORP',
#   'CensusTract': '53077000800'},
#  {'dataListIndex': '49',
#   'vin': '3FA6P0SU1H',
#   'county': 'Island',
#   'city': 'Oak Harbor',
#   'state': 'WA',
#   'postalCode': '98277',
#   'modelYear': '2017',
#   'make': 'FORD',
#   'model': 'FUSION',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '21',
#   'baseMsrp': '0',
#   'legislativeDistrict': '10',
#   'dolVehicleId': '250570589',
#   'vehicleLocation': 'POINT (-122.67499 48.287295)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53029970500'},
#  {'dataListIndex': '50',
#   'vin': '5YJ3E1EA8K',
#   'county': 'Snohomish',
#   'city': 'Bothell',
#   'state': 'WA',
#   'postalCode': '98012',
#   'modelYear': '2019',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '220',
#   'baseMsrp': '0',
#   'legislativeDistrict': '1',
#   'dolVehicleId': '338436920',
#   'vehicleLocation': 'POINT (-122.1876761 47.820517)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53061052107'},
#  {'dataListIndex': '51',
#   'vin': 'KNDCS3LF7P',
#   'county': 'King',
#   'city': 'Shoreline',
#   'state': 'WA',
#   'postalCode': '98133',
#   'modelYear': '2023',
#   'make': 'KIA',
#   'model': 'NIRO',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '33',
#   'baseMsrp': '0',
#   'legislativeDistrict': '32',
#   'dolVehicleId': '240355930',
#   'vehicleLocation': 'POINT (-122.34584 47.76726)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033020700'},
#  {'dataListIndex': '52',
#   'vin': '5YJ3E1EBXK',
#   'county': 'King',
#   'city': 'Shoreline',
#   'state': 'WA',
#   'postalCode': '98177',
#   'modelYear': '2019',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '220',
#   'baseMsrp': '0',
#   'legislativeDistrict': '32',
#   'dolVehicleId': '310953751',
#   'vehicleLocation': 'POINT (-122.382425 47.77279)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033020100'},
#  {'dataListIndex': '53',
#   'vin': '1G1FZ6S0XL',
#   'county': 'Kitsap',
#   'city': 'Seabeck',
#   'state': 'WA',
#   'postalCode': '98380',
#   'modelYear': '2020',
#   'make': 'CHEVROLET',
#   'model': 'BOLT EV',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '259',
#   'baseMsrp': '0',
#   'legislativeDistrict': '35',
#   'dolVehicleId': '138832844',
#   'vehicleLocation': 'POINT (-122.847462 47.63836)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035092000'},
#  {'dataListIndex': '54',
#   'vin': 'JT3GS10V32',
#   'county': 'King',
#   'city': 'Sammamish',
#   'state': 'WA',
#   'postalCode': '98075',
#   'modelYear': '2002',
#   'make': 'TOYOTA',
#   'model': 'RAV4',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '95',
#   'baseMsrp': '0',
#   'legislativeDistrict': '41',
#   'dolVehicleId': '175935672',
#   'vehicleLocation': 'POINT (-122.03309 47.58153)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033032207'},
#  {'dataListIndex': '55',
#   'vin': '5YJ3E1EA1J',
#   'county': 'King',
#   'city': 'Issaquah',
#   'state': 'WA',
#   'postalCode': '98027',
#   'modelYear': '2018',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '215',
#   'baseMsrp': '0',
#   'legislativeDistrict': '41',
#   'dolVehicleId': '347726956',
#   'vehicleLocation': 'POINT (-122.03646 47.534065)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033025006'},
#  {'dataListIndex': '56',
#   'vin': 'KM8JFDA26P',
#   'county': 'Snohomish',
#   'city': 'Monroe',
#   'state': 'WA',
#   'postalCode': '98272',
#   'modelYear': '2023',
#   'make': 'HYUNDAI',
#   'model': 'TUCSON',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '33',
#   'baseMsrp': '0',
#   'legislativeDistrict': '39',
#   'dolVehicleId': '252501987',
#   'vehicleLocation': 'POINT (-121.972215 47.85674)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53061052203'},
#  {'dataListIndex': '57',
#   'vin': '5YJXCBE41G',
#   'county': 'Kitsap',
#   'city': 'Silverdale',
#   'state': 'WA',
#   'postalCode': '98383',
#   'modelYear': '2016',
#   'make': 'TESLA',
#   'model': 'MODEL X',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '200',
#   'baseMsrp': '0',
#   'legislativeDistrict': '23',
#   'dolVehicleId': '226085744',
#   'vehicleLocation': 'POINT (-122.668076 47.665978)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035091302'},
#  {'dataListIndex': '58',
#   'vin': 'WBY1Z4C53E',
#   'county': 'Kitsap',
#   'city': 'Bainbridge Island',
#   'state': 'WA',
#   'postalCode': '98110',
#   'modelYear': '2014',
#   'make': 'BMW',
#   'model': 'I3',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '72',
#   'baseMsrp': '0',
#   'legislativeDistrict': '23',
#   'dolVehicleId': '243689834',
#   'vehicleLocation': 'POINT (-122.5235781 47.6293323)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035091002'},
#  {'dataListIndex': '59',
#   'vin': '1G1FY6S04L',
#   'county': 'King',
#   'city': 'Shoreline',
#   'state': 'WA',
#   'postalCode': '98177',
#   'modelYear': '2020',
#   'make': 'CHEVROLET',
#   'model': 'BOLT EV',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '259',
#   'baseMsrp': '0',
#   'legislativeDistrict': '32',
#   'dolVehicleId': '101572810',
#   'vehicleLocation': 'POINT (-122.382425 47.77279)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033020800'},
#  {'dataListIndex': '60',
#   'vin': 'KNDRJDLH5N',
#   'county': 'Thurston',
#   'city': 'Yelm',
#   'state': 'WA',
#   'postalCode': '98597',
#   'modelYear': '2022',
#   'make': 'KIA',
#   'model': 'SORENTO',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '32',
#   'baseMsrp': '0',
#   'legislativeDistrict': '2',
#   'dolVehicleId': '207310582',
#   'vehicleLocation': 'POINT (-122.61023 46.94126)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53067012530'},
#  {'dataListIndex': '61',
#   'vin': 'WBA8E1C50H',
#   'county': 'King',
#   'city': 'Bellevue',
#   'state': 'WA',
#   'postalCode': '98006',
#   'modelYear': '2017',
#   'make': 'BMW',
#   'model': '330E',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '14',
#   'baseMsrp': '44100',
#   'legislativeDistrict': '41',
#   'dolVehicleId': '477193174',
#   'vehicleLocation': 'POINT (-122.16937 47.571015)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033024901'},
#  {'dataListIndex': '62',
#   'vin': '5YJSA1CPXD',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98112',
#   'modelYear': '2013',
#   'make': 'TESLA',
#   'model': 'MODEL S',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '208',
#   'baseMsrp': '69900',
#   'legislativeDistrict': '43',
#   'dolVehicleId': '103275168',
#   'vehicleLocation': 'POINT (-122.306935 47.62441)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033006300'},
#  {'dataListIndex': '63',
#   'vin': 'JN1AZ0CP5C',
#   'county': 'Snohomish',
#   'city': 'Lake Stevens',
#   'state': 'WA',
#   'postalCode': '98258',
#   'modelYear': '2012',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '73',
#   'baseMsrp': '0',
#   'legislativeDistrict': '44',
#   'dolVehicleId': '165573152',
#   'vehicleLocation': 'POINT (-122.112265 48.0047)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53061052607'},
#  {'dataListIndex': '64',
#   'vin': '5YJYGDEE8L',
#   'county': 'Thurston',
#   'city': 'Tumwater',
#   'state': 'WA',
#   'postalCode': '98501',
#   'modelYear': '2020',
#   'make': 'TESLA',
#   'model': 'MODEL Y',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '291',
#   'baseMsrp': '0',
#   'legislativeDistrict': '35',
#   'dolVehicleId': '124633715',
#   'vehicleLocation': 'POINT (-122.89692 47.043535)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53067011720'},
#  {'dataListIndex': '65',
#   'vin': 'JN1AZ0CP1C',
#   'county': 'King',
#   'city': 'Kenmore',
#   'state': 'WA',
#   'postalCode': '98028',
#   'modelYear': '2012',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '73',
#   'baseMsrp': '0',
#   'legislativeDistrict': '46',
#   'dolVehicleId': '158914675',
#   'vehicleLocation': 'POINT (-122.2504747 47.7617128)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033022102'},
#  {'dataListIndex': '66',
#   'vin': '5YJXCDE4XL',
#   'county': 'Thurston',
#   'city': 'Olympia',
#   'state': 'WA',
#   'postalCode': '98502',
#   'modelYear': '2020',
#   'make': 'TESLA',
#   'model': 'MODEL X',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '289',
#   'baseMsrp': '0',
#   'legislativeDistrict': '22',
#   'dolVehicleId': '127274675',
#   'vehicleLocation': 'POINT (-122.92145 47.045935)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53067011100'},
#  {'dataListIndex': '67',
#   'vin': '2C4RC1N70L',
#   'county': 'Thurston',
#   'city': 'Olympia',
#   'state': 'WA',
#   'postalCode': '98501',
#   'modelYear': '2020',
#   'make': 'CHRYSLER',
#   'model': 'PACIFICA',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '32',
#   'baseMsrp': '0',
#   'legislativeDistrict': '22',
#   'dolVehicleId': '139479049',
#   'vehicleLocation': 'POINT (-122.89692 47.043535)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53067010400'},
#  {'dataListIndex': '68',
#   'vin': 'YV4BR0DM4L',
#   'county': 'King',
#   'city': 'Burien',
#   'state': 'WA',
#   'postalCode': '98166',
#   'modelYear': '2020',
#   'make': 'VOLVO',
#   'model': 'XC60',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '19',
#   'baseMsrp': '0',
#   'legislativeDistrict': '34',
#   'dolVehicleId': '106963650',
#   'vehicleLocation': 'POINT (-122.34102 47.46593)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033027800'},
#  {'dataListIndex': '69',
#   'vin': '1N4AZ0CP9D',
#   'county': 'King',
#   'city': 'Tukwila',
#   'state': 'WA',
#   'postalCode': '98168',
#   'modelYear': '2013',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '75',
#   'baseMsrp': '0',
#   'legislativeDistrict': '11',
#   'dolVehicleId': '164742420',
#   'vehicleLocation': 'POINT (-122.286465 47.476)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033026200'},
#  {'dataListIndex': '70',
#   'vin': '5YJSA1DP8D',
#   'county': 'Snohomish',
#   'city': 'Stanwood',
#   'state': 'WA',
#   'postalCode': '98292',
#   'modelYear': '2013',
#   'make': 'TESLA',
#   'model': 'MODEL S',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '208',
#   'baseMsrp': '69900',
#   'legislativeDistrict': '10',
#   'dolVehicleId': '111162012',
#   'vehicleLocation': 'POINT (-122.3684051 48.2414921)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53061053202'},
#  {'dataListIndex': '71',
#   'vin': '1G1RC6S53J',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98109',
#   'modelYear': '2018',
#   'make': 'CHEVROLET',
#   'model': 'VOLT',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '53',
#   'baseMsrp': '0',
#   'legislativeDistrict': '36',
#   'dolVehicleId': '180154600',
#   'vehicleLocation': 'POINT (-122.34848 47.632405)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033006800'},
#  {'dataListIndex': '72',
#   'vin': 'JN1AZ0CP0C',
#   'county': 'King',
#   'city': 'Sammamish',
#   'state': 'WA',
#   'postalCode': '98075',
#   'modelYear': '2012',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '73',
#   'baseMsrp': '0',
#   'legislativeDistrict': '41',
#   'dolVehicleId': '122729736',
#   'vehicleLocation': 'POINT (-122.03309 47.58153)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033032213'},
#  {'dataListIndex': '73',
#   'vin': '5YJ3E1EA4P',
#   'county': 'Kitsap',
#   'city': 'Poulsbo',
#   'state': 'WA',
#   'postalCode': '98370',
#   'modelYear': '2023',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '23',
#   'dolVehicleId': '233664560',
#   'vehicleLocation': 'POINT (-122.64177 47.737525)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035090502'},
#  {'dataListIndex': '74',
#   'vin': '5YJYGDEE8M',
#   'county': 'Snohomish',
#   'city': 'Arlington',
#   'state': 'WA',
#   'postalCode': '98223',
#   'modelYear': '2021',
#   'make': 'TESLA',
#   'model': 'MODEL Y',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '39',
#   'dolVehicleId': '169400570',
#   'vehicleLocation': 'POINT (-122.12324 48.19485)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53061053507'},
#  {'dataListIndex': '75',
#   'vin': 'KNDJP3AE1G',
#   'county': 'King',
#   'city': 'Maple Valley',
#   'state': 'WA',
#   'postalCode': '98038',
#   'modelYear': '2016',
#   'make': 'KIA',
#   'model': 'SOUL',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '93',
#   'baseMsrp': '31950',
#   'legislativeDistrict': '5',
#   'dolVehicleId': '263895950',
#   'vehicleLocation': 'POINT (-122.05191 47.357985)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033032011'},
#  {'dataListIndex': '76',
#   'vin': 'KNDPZDAH8P',
#   'county': 'Kitsap',
#   'city': 'Poulsbo',
#   'state': 'WA',
#   'postalCode': '98370',
#   'modelYear': '2023',
#   'make': 'KIA',
#   'model': 'SPORTAGE',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '34',
#   'baseMsrp': '0',
#   'legislativeDistrict': '23',
#   'dolVehicleId': '241599438',
#   'vehicleLocation': 'POINT (-122.64177 47.737525)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035090201'},
#  {'dataListIndex': '77',
#   'vin': 'WVGJNPE23N',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98116',
#   'modelYear': '2022',
#   'make': 'VOLKSWAGEN',
#   'model': 'ID.4',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '34',
#   'dolVehicleId': '225909687',
#   'vehicleLocation': 'POINT (-122.38679 47.56484)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033009702'},
#  {'dataListIndex': '78',
#   'vin': '5UXTA6C04N',
#   'county': 'Kitsap',
#   'city': 'Bremerton',
#   'state': 'WA',
#   'postalCode': '98312',
#   'modelYear': '2022',
#   'make': 'BMW',
#   'model': 'X5',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '30',
#   'baseMsrp': '0',
#   'legislativeDistrict': '35',
#   'dolVehicleId': '194341269',
#   'vehicleLocation': 'POINT (-122.65223 47.57192)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035080900'},
#  {'dataListIndex': '79',
#   'vin': '5YJXCDE22J',
#   'county': 'King',
#   'city': 'Medina',
#   'state': 'WA',
#   'postalCode': '98039',
#   'modelYear': '2018',
#   'make': 'TESLA',
#   'model': 'MODEL X',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '238',
#   'baseMsrp': '0',
#   'legislativeDistrict': '48',
#   'dolVehicleId': '280926523',
#   'vehicleLocation': 'POINT (-122.228025 47.61598)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033024200'},
#  {'dataListIndex': '80',
#   'vin': 'JN1AZ0CP4B',
#   'county': 'King',
#   'city': 'Renton',
#   'state': 'WA',
#   'postalCode': '98056',
#   'modelYear': '2011',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '73',
#   'baseMsrp': '0',
#   'legislativeDistrict': '11',
#   'dolVehicleId': '244963967',
#   'vehicleLocation': 'POINT (-122.180505 47.500055)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033025601'},
#  {'dataListIndex': '81',
#   'vin': 'WBY1Z2C51E',
#   'county': 'Thurston',
#   'city': 'Olympia',
#   'state': 'WA',
#   'postalCode': '98502',
#   'modelYear': '2014',
#   'make': 'BMW',
#   'model': 'I3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '81',
#   'baseMsrp': '0',
#   'legislativeDistrict': '22',
#   'dolVehicleId': '149282514',
#   'vehicleLocation': 'POINT (-122.92145 47.045935)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
# ...
#   'vehicleLocation': 'POINT (-122.34301 47.659185)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033001800'},
#  {'dataListIndex': '474',
#   'vin': '5YJYGDEE6M',
#   'county': 'King',
#   'city': 'Redmond',
#   'state': 'WA',
#   'postalCode': '98053',
#   'modelYear': '2021',
#   'make': 'TESLA',
#   'model': 'MODEL Y',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '45',
#   'dolVehicleId': '161599014',
#   'vehicleLocation': 'POINT (-122.0370611 47.6887161)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033032332'},
#  {'dataListIndex': '475',
#   'vin': '1N4BZ1CP0K',
#   'county': 'Whatcom',
#   'city': 'Bellingham',
#   'state': 'WA',
#   'postalCode': '98225',
#   'modelYear': '2019',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '150',
#   'baseMsrp': '0',
#   'legislativeDistrict': '40',
#   'dolVehicleId': '477314127',
#   'vehicleLocation': 'POINT (-122.486115 48.761615)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM COUNTY',
#   'CensusTract': '53073001202'},
#  {'dataListIndex': '476',
#   'vin': '1N4AZ0CP6E',
#   'county': 'Snohomish',
#   'city': 'Marysville',
#   'state': 'WA',
#   'postalCode': '98270',
#   'modelYear': '2014',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '84',
#   'baseMsrp': '0',
#   'legislativeDistrict': '38',
#   'dolVehicleId': '289423739',
#   'vehicleLocation': 'POINT (-122.17673 48.05542)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53061052904'},
#  {'dataListIndex': '477',
#   'vin': '5YJ3E1EA5P',
#   'county': 'King',
#   'city': 'Issaquah',
#   'state': 'WA',
#   'postalCode': '98029',
#   'modelYear': '2023',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '5',
#   'dolVehicleId': '239781069',
#   'vehicleLocation': 'POINT (-121.999595 47.547635)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033032220'},
#  {'dataListIndex': '478',
#   'vin': '5YJ3E1EA2L',
#   'county': 'Kitsap',
#   'city': 'Port Orchard',
#   'state': 'WA',
#   'postalCode': '98366',
#   'modelYear': '2020',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '266',
#   'baseMsrp': '0',
#   'legislativeDistrict': '26',
#   'dolVehicleId': '6249078',
#   'vehicleLocation': 'POINT (-122.639265 47.5373)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53035092600'},
#  {'dataListIndex': '479',
#   'vin': '5YJ3E1EB5P',
#   'county': 'King',
#   'city': 'Shoreline',
#   'state': 'WA',
#   'postalCode': '98177',
#   'modelYear': '2023',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '32',
#   'dolVehicleId': '245715844',
#   'vehicleLocation': 'POINT (-122.382425 47.77279)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033020800'},
#  {'dataListIndex': '480',
#   'vin': '7SAYGDEE2P',
#   'county': 'Clark',
#   'city': 'La Center',
#   'state': 'WA',
#   'postalCode': '98629',
#   'modelYear': '2023',
#   'make': 'TESLA',
#   'model': 'MODEL Y',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '18',
#   'dolVehicleId': '251668329',
#   'vehicleLocation': 'POINT (-122.6706246 45.8662548)',
#   'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)',
#   'CensusTract': '53011040201'},
#  {'dataListIndex': '481',
#   'vin': 'YV4BR0CL6K',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98177',
#   'modelYear': '2019',
#   'make': 'VOLVO',
#   'model': 'XC90',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '17',
#   'baseMsrp': '0',
#   'legislativeDistrict': '36',
#   'dolVehicleId': '326903881',
#   'vehicleLocation': 'POINT (-122.382425 47.77279)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033001600'},
#  {'dataListIndex': '482',
#   'vin': '5YJSA1E26J',
#   'county': 'Pierce',
#   'city': 'Lakewood',
#   'state': 'WA',
#   'postalCode': '98498',
#   'modelYear': '2018',
#   'make': 'TESLA',
#   'model': 'MODEL S',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '249',
#   'baseMsrp': '0',
#   'legislativeDistrict': '28',
#   'dolVehicleId': '131349165',
#   'vehicleLocation': 'POINT (-122.547645 47.176685)',
#   'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY',
#   'CensusTract': '53053072106'},
#  {'dataListIndex': '483',
#   'vin': 'JTMABABA9P',
#   'county': 'King',
#   'city': 'Tukwila',
#   'state': 'WA',
#   'postalCode': '98188',
#   'modelYear': '2023',
#   'make': 'SUBARU',
#   'model': 'SOLTERRA',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '11',
#   'dolVehicleId': '252339734',
#   'vehicleLocation': 'POINT (-122.29179 47.43473)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033028200'},
#  {'dataListIndex': '484',
#   'vin': '5YJXCAE2XL',
#   'county': 'King',
#   'city': 'Bellevue',
#   'state': 'WA',
#   'postalCode': '98008',
#   'modelYear': '2020',
#   'make': 'TESLA',
#   'model': 'MODEL X',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '293',
#   'baseMsrp': '0',
#   'legislativeDistrict': '48',
#   'dolVehicleId': '2096342',
#   'vehicleLocation': 'POINT (-122.11832 47.6245)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033023100'},
#  {'dataListIndex': '485',
#   'vin': '1N4BZ0CP6H',
#   'county': 'King',
#   'city': 'Bellevue',
#   'state': 'WA',
#   'postalCode': '98006',
#   'modelYear': '2017',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '107',
#   'baseMsrp': '0',
#   'legislativeDistrict': '41',
#   'dolVehicleId': '348003407',
#   'vehicleLocation': 'POINT (-122.16937 47.571015)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033024905'},
#  {'dataListIndex': '486',
#   'vin': '7SAYGDEE4P',
#   'county': 'King',
#   'city': 'Bellevue',
#   'state': 'WA',
#   'postalCode': '98005',
#   'modelYear': '2023',
#   'make': 'TESLA',
#   'model': 'MODEL Y',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '41',
#   'dolVehicleId': '232642511',
#   'vehicleLocation': 'POINT (-122.16085 47.624515)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033023601'},
#  {'dataListIndex': '487',
#   'vin': 'WAUSPBFF1H',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98102',
#   'modelYear': '2017',
#   'make': 'AUDI',
#   'model': 'A3',
#   'electricVehicleType': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'cleanAlternativeFuelVehicle': 'Not eligible due to low battery range',
#   'electricRange': '16',
#   'baseMsrp': '0',
#   'legislativeDistrict': '43',
#   'dolVehicleId': '135207054',
#   'vehicleLocation': 'POINT (-122.3223156 47.6402108)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033007501'},
#  {'dataListIndex': '488',
#   'vin': '7SAYGDEE0P',
#   'county': 'King',
#   'city': 'Woodinville',
#   'state': 'WA',
#   'postalCode': '98072',
#   'modelYear': '2023',
#   'make': 'TESLA',
#   'model': 'MODEL Y',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '45',
#   'dolVehicleId': '230807286',
#   'vehicleLocation': 'POINT (-122.151665 47.75855)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033021906'},
#  {'dataListIndex': '489',
#   'vin': '1N4BZ1CP4K',
#   'county': 'Clark',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'postalCode': '98682',
#   'modelYear': '2019',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '150',
#   'baseMsrp': '0',
#   'legislativeDistrict': '17',
#   'dolVehicleId': '106928818',
#   'vehicleLocation': 'POINT (-122.5146473 45.67862)',
#   'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)',
#   'CensusTract': '53011040713'},
#  {'dataListIndex': '490',
#   'vin': '5YJ3E1EB0M',
#   'county': 'King',
#   'city': 'Woodinville',
#   'state': 'WA',
#   'postalCode': '98072',
#   'modelYear': '2021',
#   'make': 'TESLA',
#   'model': 'MODEL 3',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '45',
#   'dolVehicleId': '161665864',
#   'vehicleLocation': 'POINT (-122.151665 47.75855)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033021802'},
#  {'dataListIndex': '491',
#   'vin': '7SAYGDEE3P',
#   'county': 'Clark',
#   'city': 'Brush Prairie',
#   'state': 'WA',
#   'postalCode': '98606',
#   'modelYear': '2023',
#   'make': 'TESLA',
#   'model': 'MODEL Y',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '17',
#   'dolVehicleId': '223894352',
#   'vehicleLocation': 'POINT (-122.5485715 45.7336587)',
#   'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)',
#   'CensusTract': '53011040715'},
#  {'dataListIndex': '492',
#   'vin': '1V25MPE80P',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98103',
#   'modelYear': '2023',
#   'make': 'VOLKSWAGEN',
#   'model': 'ID.4',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '43',
#   'dolVehicleId': '240635825',
#   'vehicleLocation': 'POINT (-122.34301 47.659185)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033005000'},
#  {'dataListIndex': '493',
#   'vin': '5YJXCBE45H',
#   'county': 'King',
#   'city': 'Kent',
#   'state': 'WA',
#   'postalCode': '98031',
#   'modelYear': '2017',
#   'make': 'TESLA',
#   'model': 'MODEL X',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '200',
#   'baseMsrp': '0',
#   'legislativeDistrict': '47',
#   'dolVehicleId': '141889702',
#   'vehicleLocation': 'POINT (-122.2012521 47.3931814)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033029406'},
#  {'dataListIndex': '494',
#   'vin': '5YJYGAEE0M',
#   'county': 'King',
#   'city': 'Woodinville',
#   'state': 'WA',
#   'postalCode': '98072',
#   'modelYear': '2021',
#   'make': 'TESLA',
#   'model': 'MODEL Y',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '45',
#   'dolVehicleId': '148958365',
#   'vehicleLocation': 'POINT (-122.151665 47.75855)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033021802'},
#  {'dataListIndex': '495',
#   'vin': 'WB523CF01P',
#   'county': 'King',
#   'city': 'Issaquah',
#   'state': 'WA',
#   'postalCode': '98029',
#   'modelYear': '2023',
#   'make': 'BMW',
#   'model': 'IX',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '5',
#   'dolVehicleId': '239713589',
#   'vehicleLocation': 'POINT (-121.999595 47.547635)',
#   'electricUtility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   'CensusTract': '53033032220'},
#  {'dataListIndex': '496',
#   'vin': '3C3CFFGE9H',
#   'county': 'Thurston',
#   'city': 'Olympia',
#   'state': 'WA',
#   'postalCode': '98501',
#   'modelYear': '2017',
#   'make': 'FIAT',
#   'model': '500',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '84',
#   'baseMsrp': '0',
#   'legislativeDistrict': '22',
#   'dolVehicleId': '102382829',
#   'vehicleLocation': 'POINT (-122.89692 47.043535)',
#   'electricUtility': 'PUGET SOUND ENERGY INC',
#   'CensusTract': '53067010300'},
#  {'dataListIndex': '497',
#   'vin': '1G1FZ6S0XP',
#   'county': 'Jefferson',
#   'city': 'Port Townsend',
#   'state': 'WA',
#   'postalCode': '98368',
#   'modelYear': '2023',
#   'make': 'CHEVROLET',
#   'model': 'BOLT EUV',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '24',
#   'dolVehicleId': '224737089',
#   'vehicleLocation': 'POINT (-122.7644197 48.1195874)',
#   'electricUtility': 'BONNEVILLE POWER ADMINISTRATION||PUGET SOUND ENERGY INC||PUD NO 1 OF JEFFERSON COUNTY',
#   'CensusTract': '53031950604'},
#  {'dataListIndex': '498',
#   'vin': '5YJYGDEEXM',
#   'county': 'King',
#   'city': 'Seattle',
#   'state': 'WA',
#   'postalCode': '98109',
#   'modelYear': '2021',
#   'make': 'TESLA',
#   'model': 'MODEL Y',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Eligibility unknown as battery range has not been researched',
#   'electricRange': '0',
#   'baseMsrp': '0',
#   'legislativeDistrict': '36',
#   'dolVehicleId': '135274814',
#   'vehicleLocation': 'POINT (-122.34848 47.632405)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033007002'},
#  {'dataListIndex': '499',
#   'vin': '1N4AZ0CP7F',
#   'county': 'King',
#   'city': 'Shoreline',
#   'state': 'WA',
#   'postalCode': '98155',
#   'modelYear': '2015',
#   'make': 'NISSAN',
#   'model': 'LEAF',
#   'electricVehicleType': 'Battery Electric Vehicle (BEV)',
#   'cleanAlternativeFuelVehicle': 'Clean Alternative Fuel Vehicle Eligible',
#   'electricRange': '84',
#   'baseMsrp': '0',
#   'legislativeDistrict': '32',
#   'dolVehicleId': '138211412',
#   'vehicleLocation': 'POINT (-122.3175 47.7578146)',
#   'electricUtility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   'CensusTract': '53033020500'}]

# %%
df = pd.DataFrame(data_1)
df
# Out:
#     dataListIndex         vin     county           city state postalCode  \
# 0               0  KM8K33AGXL       King        Seattle    WA      98103
# 1               1  1C4RJYB61N       King        Bothell    WA      98011
# 2               2  1C4RJYD61P     Yakima         Yakima    WA      98908
# 3               3  5YJ3E1EA7J       King       Kirkland    WA      98034
# 4               4  WBY7Z8C5XJ   Thurston        Olympia    WA      98501
# ..            ...         ...        ...            ...   ...        ...
# 495           495  WB523CF01P       King       Issaquah    WA      98029
# 496           496  3C3CFFGE9H   Thurston        Olympia    WA      98501
# 497           497  1G1FZ6S0XP  Jefferson  Port Townsend    WA      98368
# 498           498  5YJYGDEEXM       King        Seattle    WA      98109
# 499           499  1N4AZ0CP7F       King      Shoreline    WA      98155
#
#     modelYear       make           model  \
# 0        2020    HYUNDAI            KONA
# 1        2022       JEEP  GRAND CHEROKEE
# 2        2023       JEEP  GRAND CHEROKEE
# 3        2018      TESLA         MODEL 3
# 4        2018        BMW              I3
# ..        ...        ...             ...
# 495      2023        BMW              IX
# 496      2017       FIAT             500
# 497      2023  CHEVROLET        BOLT EUV
# 498      2021      TESLA         MODEL Y
# 499      2015     NISSAN            LEAF
#
#                         electricVehicleType  \
# 0            Battery Electric Vehicle (BEV)
# 1    Plug-in Hybrid Electric Vehicle (PHEV)
# 2    Plug-in Hybrid Electric Vehicle (PHEV)
# 3            Battery Electric Vehicle (BEV)
# 4    Plug-in Hybrid Electric Vehicle (PHEV)
# ..                                      ...
# 495          Battery Electric Vehicle (BEV)
# 496          Battery Electric Vehicle (BEV)
# 497          Battery Electric Vehicle (BEV)
# 498          Battery Electric Vehicle (BEV)
# 499          Battery Electric Vehicle (BEV)
#
#                            cleanAlternativeFuelVehicle electricRange baseMsrp  \
# 0              Clean Alternative Fuel Vehicle Eligible           258        0
# 1                Not eligible due to low battery range            25        0
# 2                Not eligible due to low battery range            25        0
# 3              Clean Alternative Fuel Vehicle Eligible           215        0
# 4              Clean Alternative Fuel Vehicle Eligible            97        0
# ..                                                 ...           ...      ...
# 495  Eligibility unknown as battery range has not b...             0        0
# 496            Clean Alternative Fuel Vehicle Eligible            84        0
# 497  Eligibility unknown as battery range has not b...             0        0
# 498  Eligibility unknown as battery range has not b...             0        0
# 499            Clean Alternative Fuel Vehicle Eligible            84        0
#
#     legislativeDistrict dolVehicleId                  vehicleLocation  \
# 0                    43    249675142     POINT (-122.34301 47.659185)
# 1                     1    233928502     POINT (-122.20578 47.762405)
# 2                    14    229675939  POINT (-120.6027202 46.5965625)
# 3                    45    104714466     POINT (-122.209285 47.71124)
# 4                    22    185498386     POINT (-122.89692 47.043535)
# ..                  ...          ...                              ...
# 495                   5    239713589    POINT (-121.999595 47.547635)
# 496                  22    102382829     POINT (-122.89692 47.043535)
# 497                  24    224737089  POINT (-122.7644197 48.1195874)
# 498                  36    135274814     POINT (-122.34848 47.632405)
# 499                  32    138211412     POINT (-122.3175 47.7578146)
#
#                                        electricUtility  CensusTract
# 0         CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)  53033004800
# 1        PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)  53033021804
# 2                                           PACIFICORP  53077002900
# 3        PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)  53033021903
# 4                               PUGET SOUND ENERGY INC  53067010700
# ..                                                 ...          ...
# 495      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)  53033032220
# 496                             PUGET SOUND ENERGY INC  53067010300
# 497  BONNEVILLE POWER ADMINISTRATION||PUGET SOUND E...  53031950604
# 498       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)  53033007002
# 499       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)  53033020500
#
# [500 rows x 18 columns]

# %%
df.dtypes
