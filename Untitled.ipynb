# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
my_key = os.getenv("API_KEY")

# %%
import requests

# %%
url = "https://electric-vehicle-data2.p.rapidapi.com/records"
querystring = {"dataListIndex":">=0","limit":"500","orderBy":"dataListIndex_asc","index":"0"}
headers = {
	"x-rapidapi-key": "017c936a82msh8860646249c65a4p13c03bjsn9438dd108cbd",
	"x-rapidapi-host": "electric-vehicle-data2.p.rapidapi.com"}

# %%
response = requests.get(url, headers=headers, params=querystring)

# %%
response.json()

# %%
response.status_code
# Out:
# 503

# %%
import pandas as pd

# %%
data = response.json()

# %%
#data

# %%
data_1 = data["data"]
#data_1

# %%
df = pd.DataFrame(data_1)
df
# Out:
#     dataListIndex         vin     county           city state postalCode  \
# 0               0  KM8K33AGXL       King        Seattle    WA      98103
# 1               1  1C4RJYB61N       King        Bothell    WA      98011
# 2               2  1C4RJYD61P     Yakima         Yakima    WA      98908
# 3               3  5YJ3E1EA7J       King       Kirkland    WA      98034
# 4               4  WBY7Z8C5XJ   Thurston        Olympia    WA      98501
# ..            ...         ...        ...            ...   ...        ...
# 495           495  WB523CF01P       King       Issaquah    WA      98029
# 496           496  3C3CFFGE9H   Thurston        Olympia    WA      98501
# 497           497  1G1FZ6S0XP  Jefferson  Port Townsend    WA      98368
# 498           498  5YJYGDEEXM       King        Seattle    WA      98109
# 499           499  1N4AZ0CP7F       King      Shoreline    WA      98155
#
#     modelYear       make           model  \
# 0        2020    HYUNDAI            KONA
# 1        2022       JEEP  GRAND CHEROKEE
# 2        2023       JEEP  GRAND CHEROKEE
# 3        2018      TESLA         MODEL 3
# 4        2018        BMW              I3
# ..        ...        ...             ...
# 495      2023        BMW              IX
# 496      2017       FIAT             500
# 497      2023  CHEVROLET        BOLT EUV
# 498      2021      TESLA         MODEL Y
# 499      2015     NISSAN            LEAF
#
#                         electricVehicleType  \
# 0            Battery Electric Vehicle (BEV)
# 1    Plug-in Hybrid Electric Vehicle (PHEV)
# 2    Plug-in Hybrid Electric Vehicle (PHEV)
# 3            Battery Electric Vehicle (BEV)
# 4    Plug-in Hybrid Electric Vehicle (PHEV)
# ..                                      ...
# 495          Battery Electric Vehicle (BEV)
# 496          Battery Electric Vehicle (BEV)
# 497          Battery Electric Vehicle (BEV)
# 498          Battery Electric Vehicle (BEV)
# 499          Battery Electric Vehicle (BEV)
#
#                            cleanAlternativeFuelVehicle electricRange baseMsrp  \
# 0              Clean Alternative Fuel Vehicle Eligible           258        0
# 1                Not eligible due to low battery range            25        0
# 2                Not eligible due to low battery range            25        0
# 3              Clean Alternative Fuel Vehicle Eligible           215        0
# 4              Clean Alternative Fuel Vehicle Eligible            97        0
# ..                                                 ...           ...      ...
# 495  Eligibility unknown as battery range has not b...             0        0
# 496            Clean Alternative Fuel Vehicle Eligible            84        0
# 497  Eligibility unknown as battery range has not b...             0        0
# 498  Eligibility unknown as battery range has not b...             0        0
# 499            Clean Alternative Fuel Vehicle Eligible            84        0
#
#     legislativeDistrict dolVehicleId                  vehicleLocation  \
# 0                    43    249675142     POINT (-122.34301 47.659185)
# 1                     1    233928502     POINT (-122.20578 47.762405)
# 2                    14    229675939  POINT (-120.6027202 46.5965625)
# 3                    45    104714466     POINT (-122.209285 47.71124)
# 4                    22    185498386     POINT (-122.89692 47.043535)
# ..                  ...          ...                              ...
# 495                   5    239713589    POINT (-121.999595 47.547635)
# 496                  22    102382829     POINT (-122.89692 47.043535)
# 497                  24    224737089  POINT (-122.7644197 48.1195874)
# 498                  36    135274814     POINT (-122.34848 47.632405)
# 499                  32    138211412     POINT (-122.3175 47.7578146)
#
#                                        electricUtility  CensusTract
# 0         CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)  53033004800
# 1        PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)  53033021804
# 2                                           PACIFICORP  53077002900
# 3        PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)  53033021903
# 4                               PUGET SOUND ENERGY INC  53067010700
# ..                                                 ...          ...
# 495      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)  53033032220
# 496                             PUGET SOUND ENERGY INC  53067010300
# 497  BONNEVILLE POWER ADMINISTRATION||PUGET SOUND E...  53031950604
# 498       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)  53033007002
# 499       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)  53033020500
#
# [500 rows x 18 columns]

# %%
df.dtypes
# Out:
# dataListIndex                  object
# vin                            object
# county                         object
# city                           object
# state                          object
# postalCode                     object
# modelYear                      object
# make                           object
# model                          object
# electricVehicleType            object
# cleanAlternativeFuelVehicle    object
# electricRange                  object
# baseMsrp                       object
# legislativeDistrict            object
# dolVehicleId                   object
# vehicleLocation                object
# electricUtility                object
# CensusTract                    object
# dtype: object

# %%
df.state.value_counts()
# Out:
# state
# WA    500
# Name: count, dtype: int64

# %%
url = "https://electric-vehicle-data2.p.rapidapi.com/state"
querystring = {"limit":"500","orderBy":"state_asc","index":"0"}
headers = {
	"x-rapidapi-key": my_key,
	"x-rapidapi-host": "electric-vehicle-data2.p.rapidapi.com"}

# %%
response = requests.get(url, headers=headers, params=querystring)

# %%
print(response.json())
# Out:
# {'data': ['AK', 'AL', 'AP', 'AR', 'AZ', 'BC', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'MN', 'MO', 'MS', 'MT', 'NC', 'NE', 'NH', 'NJ', 'NV', 'NY', 'OH', 'OR', 'PA', 'SC', 'TX', 'UT', 'VA', 'WA', 'WY'], 'count': 41, 'maxIndex': 0}

# %%
data = response.json()

# %%
states = data["data"]
states
# Out:
# ['AK',
#  'AL',
#  'AP',
#  'AR',
#  'AZ',
#  'BC',
#  'CA',
#  'CO',
#  'CT',
#  'DC',
#  'DE',
#  'FL',
#  'GA',
#  'HI',
#  'ID',
#  'IL',
#  'IN',
#  'KS',
#  'KY',
#  'LA',
#  'MA',
#  'MD',
#  'MN',
#  'MO',
#  'MS',
#  'MT',
#  'NC',
#  'NE',
#  'NH',
#  'NJ',
#  'NV',
#  'NY',
#  'OH',
#  'OR',
#  'PA',
#  'SC',
#  'TX',
#  'UT',
#  'VA',
#  'WA',
#  'WY']

# %%
url = "https://electric-vehicle-data2.p.rapidapi.com/dolVehicleId"
querystring = {"limit":"500","orderBy":"dolVehicleId_asc","index":"0"}
headers = {
	"x-rapidapi-key": my_key,
	"x-rapidapi-host": "electric-vehicle-data2.p.rapidapi.com"}

# %%
response = requests.get(url, headers=headers, params=querystring)

# %%
data = response.json()
ID = data["data"]
len(ID)
# Out:
# 500

# %%
# Out:
# ['100005',
#  '100021575',
#  '10002338',
#  '100024515',
#  '100025159',
#  '100039761',
#  '10005096',
#  '100053523',
#  '10008036',
#  '10008176',
#  '10008456',
#  '10008512',
#  '100091778',
#  '100093479',
#  '100095425',
#  '100096279',
#  '100106646',
#  '100115697',
#  '100117909',
#  '100117937',
#  '100134555',
#  '100135633',
#  '10014140',
#  '10015120',
#  '100170535',
#  '100180146',
#  '10018284',
#  '10018480',
#  '100186334',
#  '100195742',
#  '10020132',
#  '10020426',
#  '100249271',
#  '100256775',
#  '100281702',
#  '100285762',
#  '100291586',
#  '10029568',
#  '100310577',
#  '100311431',
#  '10034482',
#  '100369573',
#  '100370770',
#  '100375726',
#  '100379121',
#  '10038108',
#  '100382614',
#  '10038724',
#  '10039928',
#  '100404069',
#  '100416935',
#  '100421926',
#  '10042490',
#  '100431131',
#  '10043792',
#  '100438383',
#  '10045528',
#  '10046466',
#  '100469232',
#  '100469344',
#  '100469470',
#  '100469582',
#  '100470058',
#  '100470471',
#  '100471339',
#  '100471668',
#  '100471955',
#  '100472116',
#  '100474020',
#  '100477891',
#  '100478178',
#  '100478227',
#  '100479039',
#  '100479179',
#  '100485353',
#  '100485584',
#  '100485906',
#  '100489049',
#  '100491968',
#  '100497533',
#  '100498114',
#  '10050008',
#  '10050064',
#  '100501152',
#  '100502062',
#  '100502083',
#  '100503007',
#  '100503392',
#  '100510987',
#  '100511974',
#  '100512058',
#  '100512149',
#  '100512576',
#  '100513171',
#  '100514606',
#  '100517840',
#  '100520115',
#  '100525113',
#  '100525386',
#  '100525505',
#  '100527143',
#  '100528214',
#  '100530055',
#  '100530440',
#  '100531154',
#  '100531315',
#  '100531756',
#  '100532015',
#  '100534136',
#  '100534899',
#  '100536502',
#  '100537846',
#  '100538700',
#  '100540163',
#  '100541094',
#  '100543712',
#  '100548059',
#  '100549298',
#  '100551027',
#  '100551706',
#  '100551790',
#  '10055258',
#  '100552651',
#  '100552882',
#  '100553386',
#  '100559266',
#  '100561296',
#  '100565447',
#  '100567547',
#  '100568786',
#  '100568814',
#  '100569976',
#  '100571418',
#  '100574071',
#  '100574715',
#  '10057568',
#  '100576682',
#  '100578544',
#  '100582058',
#  '100583633',
#  '100585376',
#  '100588526',
#  '100591438',
#  '100593846',
#  '100594651',
#  '100595218',
#  '100597787',
#  '100598067',
#  '100598466',
#  '100602673',
#  '100603457',
#  '100606257',
#  '100606635',
#  '100611850',
#  '100612739',
#  '10061306',
#  '100613222',
#  '100613474',
#  '10061642',
#  '100620418',
#  '100620929',
#  '10062132',
#  '100623498',
#  '100623575',
#  '100623974',
#  '100626571',
#  '100632731',
#  '100632766',
#  '100633130',
#  '100633186',
#  '100633809',
#  '100635601',
#  '100635650',
#  '100636798',
#  '100639514',
#  '100643854',
#  '100643938',
#  '100647634',
#  '100647837',
#  '100648019',
#  '100648243',
#  '100648936',
#  '100649090',
#  '100649727',
#  '10065044',
#  '100651211',
#  '10065464',
#  '100655831',
#  '10065744',
#  '100661438',
#  '100664000',
#  '100667815',
#  '100668879',
#  '100670041',
#  '100670475',
#  '100676747',
#  '100677258',
#  '100677951',
#  '100679862',
#  '100684279',
#  '100686015',
#  '100687030',
#  '100687618',
#  '100687968',
#  '100688822',
#  '100689018',
#  '100690250',
#  '100691237',
#  '100692014',
#  '100693330',
#  '100693526',
#  '100693722',
#  '100693848',
#  '100696753',
#  '100705076',
#  '10070616',
#  '100707519',
#  '100708534',
#  '100709542',
#  '100710032',
#  '100710354',
#  '100711488',
#  '100712230',
#  '100712720',
#  '100715870',
#  '100717746',
#  '100721162',
#  '100722576',
#  '100723451',
#  '100725418',
#  '100725922',
#  '100726055',
#  '100728666',
#  '100730339',
#  '100731536',
#  '100731851',
#  '100732250',
#  '100732698',
#  '100734595',
#  '100736338',
#  '100738102',
#  '100738690',
#  '100738774',
#  '100739719',
#  '100740664',
#  '100741280',
#  '100742855',
#  '10074452',
#  '100744584',
#  '10074620',
#  '100748392',
#  '100752263',
#  '10075572',
#  '100756050',
#  '100757121',
#  '100757296',
#  '100759718',
#  '100759816',
#  '100761951',
#  '100764079',
#  '100764541',
#  '100765479',
#  '100767803',
#  '100769000',
#  '100770295',
#  '100775895',
#  '100775979',
#  '100777169',
#  '100777218',
#  '100777827',
#  '100778912',
#  '100781117',
#  '100782615',
#  '100782783',
#  '100782944',
#  '100783581',
#  '100783903',
#  '100784218',
#  '100785009',
#  '100786157',
#  '100787389',
#  '100787823',
#  '100788880',
#  '100789538',
#  '100793738',
#  '100794690',
#  '100795551',
#  '100796146',
#  '100797686',
#  '100801067',
#  '100802285',
#  '100802390',
#  '100802684',
#  '100805078',
#  '100805771',
#  '100807304',
#  '100808571',
#  '100808578',
#  '100810958',
#  '100811819',
#  '10081340',
#  '100813611',
#  '100815697',
#  '100818651',
#  '100821192',
#  '100823922',
#  '100824454',
#  '100825056',
#  '100825070',
#  '10082586',
#  '100830264',
#  '100830544',
#  '100830642',
#  '100834422',
#  '100834737',
#  '100835234',
#  '100836662',
#  '100837635',
#  '100837831',
#  '100837873',
#  '100840890',
#  '100841072',
#  '100841450',
#  '100845951',
#  '100846154',
#  '100846385',
#  '100849514',
#  '100849864',
#  '100850263',
#  '100850326',
#  '100852944',
#  '100853329',
#  '100854883',
#  '100855499',
#  '100858929',
#  '100859650',
#  '100860658',
#  '100861267',
#  '100861638',
#  '100862226',
#  '100867147',
#  '100870395',
#  '100871795',
#  '100872810',
#  '100873055',
#  '100873251',
#  '100876282',
#  '100876415',
#  '100879530',
#  '100884374',
#  '100891682',
#  '100893530',
#  '10089376',
#  '100896582',
#  '100896897',
#  '100897366',
#  '100897653',
#  '100897835',
#  '100899018',
#  '100899858',
#  '100900691',
#  '100901559',
#  '100902336',
#  '100902518',
#  '100902560',
#  '100903064',
#  '100907131',
#  '100911611',
#  '100915671',
#  '100916371',
#  '100916490',
#  '100919759',
#  '100919794',
#  '100922916',
#  '100923847',
#  '100924127',
#  '100929769',
#  '100934970',
#  '100935061',
#  '100938561',
#  '100938848',
#  '100941305',
#  '100942929',
#  '100943349',
#  '100943671',
#  '100945274',
#  '100949887',
#  '100955221',
#  '100956215',
#  '100960737',
#  '100964153',
#  '100967975',
#  '100971209',
#  '100972154',
#  '100979217',
#  '100980645',
#  '100981975',
#  '100982325',
#  '100984705',
#  '100985209',
#  '100985741',
#  '100989269',
#  '100996969',
#  '100997277',
#  '100998173',
#  '100999097',
#  '101002681',
#  '101003521',
#  '101008925',
#  '101011977',
#  '101012061',
#  '101013377',
#  '101015197',
#  '101016429',
#  '101017192',
#  '101020713',
#  '101023485',
#  '101029855',
#  '101030653',
#  '101031682',
#  '101036617',
#  '101037373',
#  '101037674',
#  '101042105',
#  '101042441',
#  '101046473',
#  '101047733',
#  '101048517',
#  '101050029',
#  '101050953',
#  '101054103',
#  '101054873',
#  '101058401',
#  '101062377',
#  '101065268',
#  '101083055',
#  '101086261',
#  '101087829',
#  '101088529',
#  '101089817',
#  '101090699',
#  '101098133',
#  '101099533',
#  '101103089',
#  '101104097',
#  '101107513',
#  '101109921',
#  '101110985',
#  '101111013',
#  '101112525',
#  '101113841',
#  '101116613',
#  '101117425',
#  '101118279',
#  '101118433',
#  '101120057',
#  '101121457',
#  '101122773',
#  '101125237',
#  '101129409',
#  '101130501',
#  '101132209',
#  '101133483',
#  '101135128',
#  '101135625',
#  '101137137',
#  '101142877',
#  '101142933',
#  '101143143',
#  '101144165',
#  '101144305',
#  '101155029',
#  '101156457',
#  '101156541',
#  '101159593',
#  '101160433',
#  '101162113',
#  '101164325',
#  '101168161',
#  '101168581',
#  '101170352',
#  '101173369',
#  '101173817',
#  '101174104',
#  '101176834',
#  '101178647',
#  '101180537',
#  '101181349',
#  '101182721',
#  '101186116',
#  '101193480',
#  '101194985',
#  '101196889',
#  '101204505',
#  '101209111',
#  '101209209',
#  '101212233',
#  '101213031',
#  '101216041',
#  '101217945']

# %%
#First lets retrieve the list of the US states within the API - possibly this wont be necessary ask ISI

url = "https://electric-vehicle-data2.p.rapidapi.com/state"
querystring = {"limit":"500","orderBy":"state_asc","index":"0"}
headers = {
	"x-rapidapi-key": my_key,
	"x-rapidapi-host": "electric-vehicle-data2.p.rapidapi.com"}

# %%
response = requests.get(url, headers=headers, params=querystring)
states_data = response.json()
states = states_data["data"]
